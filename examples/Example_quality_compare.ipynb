# %% [markdown]
# ## Import needed modules and packages

# %%
#import the geomapi package
import os
import ifcopenshell.geom as geom
import math
from scipy.spatial.transform import Rotation as R
from PIL import Image, ImageDraw
import shutil
from rdflib import Graph, URIRef, RDF
import os.path
import importlib
import numpy as np
import xml.etree.ElementTree as ET
import open3d as o3d
import uuid    
import copy
import pye57 
import ifcopenshell
import multiprocessing as mp
import time
from pathlib import Path
from typing import List
import matplotlib.pyplot as plt
import csv
import xlsxwriter

#IMPORT MODULES
from context import geomapi 
from geomapi.nodes import *
import geomapi.utils as ut
from geomapi.utils import geometryutils as gmu
import geomapi.tools as tl
from geomapi.tools import validationtools as vt
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %% [markdown]
# ## Create a SessionNode

# %%
path= os.path.join(os.path.abspath(os.path.join(os.getcwd(), os.pardir)),"tests",)

projectPath = r"C:\Data\Projects-MEETHET\012203-34-BIM-Colruyt Schoten" #os.path.join(path,'Samples12')

sn = SessionNode(subject=ut.get_folder(projectPath),projectPath= projectPath )
# print(sn.subject)
# print(sn.get_name())
# print(sn.projectPath)

an = Node(subject=sn.subject, projectPath= projectPath)

# %% [markdown]
# ## Set needed global parameters

# %%
#INPUT parameters
sn.ifcPath = None
sn.pcdPath = None

sn.tempPath = None
sn.outputPath = None

# saveCSV = True
# saveExcel = True
# saveColloredBIM = True
# saveColloredPcd = True
# #PARAMETER ADDED
saveReports = True
# saveResultPcd = True

sn.resolution = 0.05

#AVANCED
sn.keys = { 'Wall':["IfcWall", "IfcWindow","IfcDoor"],
         'Column':['IfcColumn'],
         'Beam':["IfcBeam"],
         'Slab':["IfcSlab",'IfcCovering'],
         'Roof':["IfcRoof"]}


an.t30 = 0.015 #LOA30 Treshold
an.t20 = 0.05 #LOA20 Treshold
an.t10 = 0.1 #LOA10 Treshold
an.t00 =1 #Total distance treshold
an.abs = True # use absolute values for percentages

an.Td = 0.1 #distance trechold for filtering
an.Sr=0.1 #Seach radius treshold for normal matching
an.Tdot = 0.8 #treshhold for normal matching 

an.p10 = 0.68 #cumulative percentage treshold LOA10
an.p20 = 0.68 #cumulative percentage treshold LOA20
an.p30 = 0.68 #cumulative percentage treshold LOA30

# %% [markdown]
# Create temporary directory to save working files

# %%
if not sn.tempPath:
    sn.projectProcessingPath = os.path.join(sn.projectPath, "PROCESSING")
else:
    sn.projectProcessingPath = sn.tempPath

if not os.path.isdir(sn.projectProcessingPath): #check if the folder exists
    os.mkdir(sn.projectProcessingPath)

# %% [markdown]
# Create Directory to save results

# %%
if not sn.outputPath:
    sn.projectResultsPath = os.path.join(sn.projectPath, "RESULTS")
else:
    sn.projectResultsPath = sn.outputPath

if not os.path.isdir(sn.projectResultsPath): #check if the folder exists
    os.mkdir(sn.projectResultsPath)

resultsName = "session_" + time.strftime("%Y%m%d-%H%M%S")
sn.resultsPath = os.path.join(sn.projectResultsPath, resultsName)
if not os.path.exists(sn.resultsPath):
    os.makedirs(sn.resultsPath)

# %% [markdown]
# Get the IFC file

# %%
if not sn.ifcPath:
    sn.ifcPath = os.path.join(sn.projectPath, "MODELS") #Construct the data Modelsfolder path
    if os.path.isdir(sn.ifcPath): #Check if the folder exists
        ifc2x3Path = os.path.join(sn.ifcPath, "IFC2x3") #Construct the IFC2x3 folder path
        if os.path.isdir(ifc2x3Path): #check if ther is an IFC2x3 folder present in the project
            content_ifc_dir = os.listdir(ifc2x3Path) #get the content of the folder
            if len(content_ifc_dir) > 0: #check if the folder is not empty
                #Loop over all IFC files in the current directory
                ifcFiles = []
                for ifcfile in content_ifc_dir: #for every ifc model in the folder
                    
                    if ifcfile.endswith(".ifc"):
                        ifcFiles.append(ifcfile)
                    else:
                        print("ERROR: Select an IFC file")
                if len(ifcFiles) > 1:
                    print("ERROR: Specify one IFC file to be processed")
                else:
                    sn.ifcPath = os.path.join(ifc2x3Path, ifcFiles[0])
                    print("Using IFC file: %s" % sn.ifcPath)
            else:
                print("ERROR: Selected Directory is empty %s" % ifc2x3Path)
        else:
            print("ERROR: No such directory %s" % ifc2x3Path)
    else:
        print("ERROR: No such directory %s" % sn.ifcPath)
else:
    if sn.ifcPath.endswith(".ifc"):
        print("Using IFC file: %s" % sn.ifcPath)
    else:
        print("ERROR: Select an IFC file")
# Out:
# ERROR: Select an IFC file
# Using IFC file: C:\Data\Projects-MEETHET\012203-34-BIM-Colruyt Schoten\MODELS\IFC2x3\012203-34-BIM-Colruyt_3D model_3.ifc

# %% [markdown]
# Get the input pointcloud files

# %%
if sn.pcdPath:
    if os.path.isdir(sn.pcdPath):
        dir = sn.pcdPath
        print("All pointclouds in %s will be processed" %dir)
        pcds = os.listdir(dir)
        if len(pcds) > 0:
            sn.pcdPath = []
            for pcd in pcds:
                sn.pcdPath.append(os.path.join(dir,pcd))
    elif os.path.isfile(sn.pcdPath):
        if sn.pcdPath.endswith(".pcd") or sn.pcdPath.endswith(".pts"):
            print("Pointcloud %s will be processed" % sn.pcdPath)
            pcdPath = [sn.pcdPath]
        else:
            print("ERROR: only PCD and PTS format are currently supported")
    else:
        print("ERROR: Please provide an existing path")
    
else:
    dataPath = os.path.join(sn.projectPath, "DATA")
    if os.path.exists(dataPath):
        sn.pcdPath = os.path.join(dataPath, "PCD")
        if os.path.exists(sn.pcdPath):
            dir = sn.pcdPath
            print("All pointclouds in %s will be processed" %dir)
            pcds = os.listdir(dir)
            if len(pcds) > 0:
                sn.pcdPath = []
                for pcd in pcds:
                    if pcd.endswith(".pcd"):
                        sn.pcdPath.append(os.path.join(dir,pcd))
                if not len(sn.pcdPath) > 0:
                    print("ERROR: No PCD Files found")
                    ptsPath = os.path.join(dataPath, "PTS")
                    if os.path.exists(ptsPath):
                        dir = ptsPath
                        print("All pointclouds in %s will be processed" %dir)
                        pcds = os.listdir(dir)
                        if len(pcds) > 0:
                            sn.pcdPath = []
                            for pcd in pcds:
                                if pcd.endswith(".pts"):
                                    sn.pcdPath.append(os.path.join(dir,pcd))
                            if not len(sn.pcdPath) > 0:
                                print("ERROR: No PTS Files found")
        else:
            ptsPath = os.path.join(dataPath, "PTS")
            if os.path.exists(ptsPath):
                dir = ptsPath
                print("All pointclouds in %s will be processed" %dir)
                pcds = os.listdir(dir)
                if len(pcds) > 0:
                    pcdPath = []
                    for pcd in pcds:
                        if pcd.endswith(".pts"):
                            pcdPath.append(os.path.join(dir,pcd))
                    if not len(pcdPath) > 0:
                        print("ERROR: No PTS Files found")
    else:
        print("ERROR: Provide a pointcloud")
        
print(sn.pcdPath)
# Out:
# All pointclouds in C:\Data\Projects-MEETHET\012203-34-BIM-Colruyt Schoten\DATA\PCD will be processed
# ['C:\\Data\\Projects-MEETHET\\012203-34-BIM-Colruyt Schoten\\DATA\\PCD\\interieur1.pcd', 'C:\\Data\\Projects-MEETHET\\012203-34-BIM-Colruyt Schoten\\DATA\\PCD\\interieur2.pcd', 'C:\\Data\\Projects-MEETHET\\012203-34-BIM-Colruyt Schoten\\DATA\\PCD\\interieur3.pcd', 'C:\\Data\\Projects-MEETHET\\012203-34-BIM-Colruyt Schoten\\DATA\\PCD\\interieur4.pcd', 'C:\\Data\\Projects-MEETHET\\012203-34-BIM-Colruyt Schoten\\DATA\\PCD\\interieur5.pcd']

# %% [markdown]
# Additional settings to export the results to excel or csv

# %%
# #CSV
csvFilename = "LOA_Report.csv"
csvPath = os.path.join(sn.resultsPath, csvFilename)
header = ['Name','Id', 'Class','LOA', 'LOA10', 'LOA20', 'LOA30']
csvFile = open(csvPath, 'w')
sn.csvWriter = csv.writer(csvFile)
sn.csvWriter.writerow(header)

#Excel
xlsxFilename = "LOA_Report.xlsx"
xlsxPath = os.path.join(sn.resultsPath, xlsxFilename)
sn.workbook = xlsxwriter.Workbook(xlsxPath)
sn.worksheet = sn.workbook.add_worksheet()
sn.worksheet.write(0,0,'Name')
sn.worksheet.write(0,1,'Id')
sn.worksheet.write(0,2,'Class')
sn.worksheet.write(0,3,'LOA')
sn.worksheet.write(0,4, 'LOA10')
sn.worksheet.write(0,5, 'LOA20')
sn.worksheet.write(0,6, 'LOA30')
sn.xlsxRow = 1

# %% [markdown]
# ## Create some BIMNodes

# %%
sn.bimNodes=tl.ifc_to_nodes_multiprocessing(sn.ifcPath)

# %% [markdown]
# 2. divide and save them per storey

# %%
sn.StoreyList=[]
#Open the IFC file to acces the IFC relations
ifc = ifcopenshell.open(sn.ifcPath) 
#Finf all the storeys in a building
for level, ifc_storey in enumerate(ifc.by_type("IfcBuildingStorey")):
    myIds=[]
    
    #find the ids of the elements of that storey
    for reference in ifc.get_inverse(ifc_storey):
        if reference.is_a("IfcRelContainedInSpatialStructure"):
            for product in reference.RelatedElements:
                    if product.is_a("IfcProduct"):  
                        myIds.append(product.GlobalId)

    #select all elements of that storey from bimNodes
    sn.StoreyList.append([n for n in sn.bimNodes if n.globalId in myIds])
    # [n.save_resource(projectProcessingPath) for n in myStoreyList[level] if n.resource is not None]

# %% [markdown]
# ## Assign keys to bimNodes
# Link the label defined in key to the IFCclass

# %%
for n in sn.bimNodes:
    found = False
    for key in sn.keys.keys():
        if n.className in sn.keys[key]:
            n.key = key
            found = True
    if not found:
        n.key = 'Clutter'

# %%
wallNodes=[n for n in sn.bimNodes if 'Wall' in n.className]
print(len(wallNodes))
columnNodes=[n for n in sn.bimNodes if 'Column' in n.className]
print(len(columnNodes))
beamNodes=[n for n in sn.bimNodes if 'Beam' in n.className]
print(len(beamNodes))
slabNodes=[n for n in sn.bimNodes if 'Slab' in n.className]
print(len(slabNodes))
roofNodes=[n for n in sn.bimNodes if 'Roof' in n.className]
print(len(roofNodes))
clutterNodes=[n for n in sn.bimNodes if 'Clutter' in n.className]
print(len(clutterNodes))
# Out:
# 400
# 57
# 44
# 71
# 586
# 0

# %%
for n in sn.bimNodes:
    n.name = n.key + "_" + n.globalId
    n.path = os.path.join(sn.projectProcessingPath, n.get_name() + ".ply")
    #BUG: the GlobalID as python is Case sensitive but file names ar NOT so when a globalId only differs from another by a capital letter the file was overwriten. Therefore when the file already exists a timesamp is added. This makes the functionalitie that it only saves when theh file doesnt exist unusabel because when the file already exists he will just add a timestamp
    if os.path.exists(n.path):
        n.name = n.key + "_" + n.globalId + time.strftime("%Y%m%d%H%M%S")
    
    if not n.save_resource(sn.projectProcessingPath):
        sn.bimNodes.remove(sn.bimNodes.index(n))

# %%
print(len(sn.bimNodes))
# Out:
# 1484

# %% [markdown]
# now that the preprocessing is done, we serialize each nodes' graph

# %%
graphPath=os.path.join(projectPath,'meshGraph.ttl')
tl.nodes_to_graph(nodelist=sn.bimNodes,graphPath=graphPath,save=True)
# Out:
# <Graph identifier=Nf3eeb0602f43456cb781322be9ee09d2 (<class 'rdflib.graph.Graph'>)>

# %%
print(sn.bimNodes[0].graph.serialize())
# Out:
# @prefix e57: <http://libe57.org#> .
# @prefix ifc: <http://ifcowl.openbimstandards.org/IFC2X3_Final#> .
# @prefix openlabel: <https://www.asam.net/index.php?eID=dumpFile&t=f&f=3876&token=413e8c85031ae64cc35cf42d0768627514868b2f#> .
# @prefix v4d: <https://w3id.org/v4d/core#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <file:///Surface_2380054_02lVx43qr9L9TaN1LOsKYs> a v4d:BIMNode ;
#     ifc:className "IfcSite" ;
#     ifc:globalId "02lVx43qr9L9TaN1LOsKYs" ;
#     ifc:ifcPath "MODELS\\IFC2x3\\012203-34-BIM-Colruyt_3D model_3.ifc" ;
#     e57:cartesianBounds """[ 64.32785024 175.92689883  68.78402476 275.06421504  -1.52915957
#    0.64864638]""" ;
#     e57:cartesianTransform """[[1.00000000e+00 0.00000000e+00 0.00000000e+00 1.36889052e+02]
#  [0.00000000e+00 1.00000000e+00 0.00000000e+00 1.61127316e+02]
#  [0.00000000e+00 0.00000000e+00 1.00000000e+00 1.54342748e-02]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 1.00000000e+00]]""" ;
#     e57:pointCount 6533 ;
#     v4d:faceCount 10642 ;
#     v4d:key "Clutter" ;
#     v4d:name "Clutter_02lVx43qr9L9TaN1LOsKYs20220912151918" ;
#     v4d:orientedBounds """[[ 1.75392014e+02  2.80049319e+02  1.18574931e+00]
#  [ 1.97392797e+02  7.21248473e+01  9.39521073e-01]
#  [ 5.42700574e+01  2.67234133e+02  4.25686465e-01]
#  [ 1.75405388e+02  2.80053338e+02 -1.01318530e+00]
#  [ 7.62842140e+01  5.93136805e+01 -2.01947637e+00]
#  [ 5.42834309e+01  2.67238152e+02 -1.77324814e+00]
#  [ 1.97406171e+02  7.21288664e+01 -1.25941353e+00]
#  [ 7.62708405e+01  5.93096614e+01  1.79458232e-01]]""" ;
#     v4d:path "PROCESSING\\Clutter_02lVx43qr9L9TaN1LOsKYs20220912151918.ply" ;
#     openlabel:timestamp "2022-06-01T10:08:15" .

# %% [markdown]
# if you want to delete all these resources, call del on each node

# %%
# for n in bimNodes:
#     del n.resource

# %% [markdown]
# woops, now i have to reload all the data

# %%
# [n.get_resource() for n in bimNodes]

# %% [markdown]
# now if you want to reload all these nodes from graph

# %%
# graphPath=os.path.join(projectProcessingPath,'meshGraph.ttl')
# bimNodes=tl.graph_path_to_nodes(graphPath,getResource=True)

# %%
print(sn.bimNodes[0].subject)
print(sn.bimNodes[0].resource)
# Out:
# file:///Surface_2380054_02lVx43qr9L9TaN1LOsKYs
# TriangleMesh with 6533 points and 10642 triangles.

# %% [markdown]
# ## Create PCDNodes from MeshNodes

# %%
sn.meshpcdNodes=[]
referencepcd = o3d.geometry.PointCloud()
referenceNode = PointCloudNode()
referenceNode.keys = []
referenceNode.objects = 0
for n in sn.bimNodes:
    if not n.resource is None:
        number_of_points=int(n.resource.get_surface_area()/(sn.resolution*sn.resolution))
        myPCD=n.resource.sample_points_uniformly(number_of_points=number_of_points)
        if not myPCD is None:
            myPCDNode=PointCloudNode(resource=myPCD,
                                    name= n.get_name().split("-")[0] + "-MESHPCD",
                                    subject=n.get_name().split("-")[0] + "-MESHPCD",
                                    isDerivedFromGeometry=n.subject,
                                    processed = False)
            myPCDNode.path = os.path.join(sn.projectProcessingPath, myPCDNode.get_name() + ".pcd")
            myPCDNode.save_resource(sn.projectProcessingPath)
            referencepcd.__iadd__(myPCDNode.resource)
            n.object = 1
            ids = len(myPCDNode.resource.points)
            i=0
            while i < ids:
                referenceNode.keys.append(n.object)
                i += 1 


            n.object = referenceNode.objects
            referenceNode.objects += 1

            sn.meshpcdNodes.append(myPCDNode)

referenceNode.resource = referencepcd
print(referencepcd)
print(len(referenceNode.keys))
# Out:
# PointCloud with 22731086 points.
# 22731086

# %% [markdown]
# now that the preprocessing is done, we serialize each nodes' graph

# %%
print(len(sn.bimNodes)) #247 mesh files
print(len(sn.meshpcdNodes)) #247 meshpcd files
print(referenceNode.objects)
# Out:
# 1484
# 1484
# 1484

# %%
# graphPath=os.path.join(projectProcessingPath,'meshpcdGraph.ttl')
# tl.nodes_to_graph(nodelist=pcdNodeList,graphPath=graphPath,save=True)

# %% [markdown]
# ## Create the needed images for the report

# %% [markdown]
# 1. Function to get the boundingbox of a list of geometries

# %%
# def get_boundingbox_of_list_of_geometries(geometries:List[Node]) -> np.array:
#     """Determines the global boundingbox of a group of Node containing geometries.

#     Args:
#         geometries (List[Nodes]):  list of Nodes containing a resource of which the boundingbox must be determined"
            
#     Returns:
#         np.array[3x1]
#     """
#     pcd = o3d.geometry.PointCloud()
#     for n in geometries:
#         n.get_resource()
#         if n.resource is not None:
#             pcd.__iadd__(o3d.geometry.PointCloud(gmu.get_oriented_bounds(gmu.get_cartesian_bounds(n.resource))))
#     cartesianBounds = gmu.get_cartesian_bounds(pcd.get_oriented_bounding_box())
#     return cartesianBounds

# %% [markdown]
# 2. Determine a good camera stand point for an overview image

# %%
# def optimize_camera_for_overview(geometries:List[Node]):
#     """Determines the camera position to create an overview image of a group of Nodes containing geometries.

#     Args:
#         geometries (List[Nodes]):  list of Nodes containing a resource "
            
#     Returns:
#         c center of the objects np.array[1x3]
#         c_i the camera position np.array[1x3]
#         up defines which direction is up [0,0,1] for z
#     """

#     cartesianBounds = get_boundingbox_of_list_of_geometries(geometries=geometries)
#     bbbox = gmu.get_oriented_bounding_box(cartesianBounds)

#     fov = np.pi / 3 #60 #degrees
            
#     #determine extrinsic camera parameters
#     extrinsic = np.empty((1,3), dtype=float)
    
#     c = bbbox.get_center()
#     u = bbbox.extent[0]
#     d_w = math.cos(fov/2)*u

#     #determine c_i
#     rotation_matrix = bbbox.R
#     pcd2 = o3d.geometry.PointCloud()
#     array = np.array([[c[0],c[1],c[2]+d_w]])
#     pcd2.points = o3d.utility.Vector3dVector(array)
#     c_i = np.asarray(pcd2.points[0])

#     up = [0, 0, 1]  # camera orientation

    
#     return c,c_i,up

# %%
print(len(sn.StoreyList))
for storey in sn.StoreyList:
    floor = []
    print(len(storey))
    for object in storey:
        floor.append(object.resource)
    o3d.visualization.draw_geometries(floor)

# %%
if saveReports:
    #Create images directory to save results    
    sn.imageResultDirectory = os.path.join(sn.resultsPath, "IMAGES")
    if not os.path.isdir(sn.imageResultDirectory):
        os.mkdir(sn.imageResultDirectory)

    for storey in sn.StoreyList:

        c,c_i,up = val.optimize_camera_for_overview(storey)
        
        #generate scene
        width = 640
        height = 480
        
        for element in storey:
            element.overviewImagePath = None
            if element.resource is not None:
                render = o3d.visualization.rendering.OffscreenRenderer(width,height)
        
                render.scene.camera.look_at(c, c_i, up)
                #Determine path to save the created image
                overviewImageResultName = element.name + "_OVERVIEW"
                overviewImageResultFileName = overviewImageResultName + ".png"
                overviewImageResultPath = os.path.join(sn.imageResultDirectory, overviewImageResultFileName)
                if os.path.exists(overviewImageResultPath):
                    element.name = element.key + "_" + element.globalId + time.strftime("%Y%m%d%H%M%S")
                
                element.resource.paint_uniform_color([1,0,0])
            
            
                material1 = o3d.visualization.rendering.MaterialRecord()
                material1.base_color = [1.0, 0.0, 0.0, 1.0]  # RGBA
                material1.shader = "defaultUnlit"

                render.scene.add_geometry(element.name,element.resource,material1)

                for otherElement in storey:
                    material2 = o3d.visualization.rendering.MaterialRecord()
                    material2.base_color = [0.5, 0.5, 0.5, 0.1]  # RGBA
                    material2.shader = "defaultUnlit"

                    if otherElement is not element and otherElement.resource is not None:
                        render.scene.add_geometry(otherElement.name,otherElement.resource,material2)

                #Take the image
                img = render.render_to_image()
                
                o3d.io.write_image(overviewImageResultPath, img)
                element.overviewImagePath = overviewImageResultPath
                print(element.name)
# Out:
# Clutter_2OIUz9zOHD_BYVYmX3KLcB20220912151918
# Clutter_1ft2BeOOT9IAqaQNHLnYit20220912151918
# Wall_0eCd_c4_jF3fWwzrAmFAGk20220912151918
# Clutter_0bOlnkW59DjubTltZzGQ$k20220912151918
# Wall_0bOlnkW59DjubTltZzGQyL20220912151918
# Wall_0bOlnkW59DjubTltZzGQus20220912151918
# Wall_0bOlnkW59DjubTltZzGP0i20220912151918
# Clutter_0bOlnkW59DjubTltZzGPIs20220912151918
# Wall_0bOlnkW59DjubTltZzGPUp20220912151918
# Wall_3AUUEyCM9AXg8xdG0nwgQP20220912151918
# Clutter_3AUUEyCM9AXg8xdG0nwgSm20220912151918
# Wall_3AUUEyCM9AXg8xdG0nwgHW20220912151918
# Clutter_3AUUEyCM9AXg8xdG0nwgMm20220912151918
# Clutter_3AUUEyCM9AXg8xdG0nwgMC20220912151918
# Clutter_2I1MjW3CrCRgIwhVTYKlmy20220912151918
# Clutter_157UZAQ917$vE3AxB$q0GF20220912151918
# Wall_157UZAQ917$vE3AxB$q0Th20220912151918
# Wall_0dJmiHv_TE5eZ4Ssa1hZAh20220912151918
# Wall_3r0qdwUzP0HBXErMls12vf20220912151918
# Wall_1r8UZLUsT3OvNNv5NT4wF920220912151918
# Clutter_3dTGhr_b164vU83Wm1iBTN20220912151918
# Clutter_3dTGhr_b164vU83Wm1iBUA20220912151918
# Clutter_3dTGhr_b164vU83Wm1iBZQ20220912151918
# Clutter_3dTGhr_b164vU83Wm1iBdo20220912151918
# Clutter_3dTGhr_b164vU83Wm1iBcw20220912151918
# Wall_3I8aFNY8TFCBqW6NGBIXRd20220912151918
# Wall_3RthyIUpL8WeJo4ROZ0vAu20220912151918
# Wall_3RthyIUpL8WeJo4ROZ0wrr20220912151918
# Wall_1KNSp$CQTEdOSIzPLmrPgb20220912151918
# Wall_1KNSp$CQTEdOSIzPLmrPM_20220912151918
# Clutter_0UHZztZKj4mPwBamE0_57f20220912151918
# Clutter_1QozXDlib7j8PYUNJsRHNW20220912151918
# Wall_1RDuO561TDGwO$d8Tp6EDn20220912151918
# Clutter_1RDuO561TDGwO$d8Tp6EIN20220912151918
# Wall_2_C$vMQATCFhJ8BSPrcIyy20220912151918
# Clutter_2_C$vMQATCFhJ8BSPrcIz920220912151918
# Wall_2JipTxAY90bwjOi9eE1ju920220912151918
# Clutter_2JipTxAY90bwjOi9eE1j6h20220912151918
# Clutter_2JipTxAY90bwjOi9eE1j4b20220912151918
# Wall_23Mp1K7OnEufd$s80WXEty20220912151918
# Wall_23Mp1K7OnEufd$s80WXEtx20220912151918
# Wall_23Mp1K7OnEufd$s80WXEtw20220912151918
# Slab_1V9CFFJc12EBeArfGCfo7920220912151918
# Slab_3HMEX_EA17jw_2SPypA_Xl20220912151918
# Column_35apZfCFX9QQSptxYecLRP20220912151918
# Column_35apZfCFX9QQSptxYecLC$20220912151918
# Column_21OGwNUH17ChrSoZTUPjUt20220912151918
# Column_21OGwNUH17ChrSoZTUPjTG20220912151918
# Column_2wOu5I0Eb5WuGYpSdHhTBC20220912151918
# Column_3f7qBfEOXCVuz_Bd4eLokN20220912151918
# Column_0lqc9Mqnn3$gpcpcTpK5Ir20220912151918
# Column_1UCXF__NL7NO5CMcV0_6fB20220912151918
# Column_1UCXF__NL7NO5CMcV0_6dJ20220912151918
# Column_1UCXF__NL7NO5CMcV0_6cL20220912151918
# Column_1UCXF__NL7NO5CMcV0_6YG20220912151918
# Column_3XmPHQfcL2EQPaBBHNGaNa20220912151918
# Column_3XmPHQfcL2EQPaBBHNGaNS20220912151918
# Column_3XmPHQfcL2EQPaBBHNGaUS20220912151918
# Column_3XmPHQfcL2EQPaBBHNGa2220220912151918
# Column_3XmPHQfcL2EQPaBBHNGa3320220912151918
# Column_3XmPHQfcL2EQPaBBHNGa3I20220912151918
# Column_3XmPHQfcL2EQPaBBHNGa0120220912151918
# Column_3XmPHQfcL2EQPaBBHNGa1r20220912151918
# Column_3Rpde4K2j79xahimOYSH2120220912151918
# Column_3Rpde4K2j79xahimOYSH5B20220912151918
# Column_3Rpde4K2j79xahimOYSH7r20220912151918
# Column_3Rpde4K2j79xahimOYSHxn20220912151918
# Column_3rsfNClEb0Ix66ynEexYHl20220912151918
# Column_1O3HLsFkL5J8ueFln_90yM20220912151918
# Column_1O3HLsFkL5J8ueFln_90y120220912151918
# Column_1O3HLsFkL5J8ueFln_90ym20220912152305
# Column_1O3HLsFkL5J8ueFln_90yZ20220912151918
# Wall_0bI$TQkt12R8wsCRj$F9wU20220912151918
# Wall_3D21rLn4n3$Be$XO40_1BN20220912151918
# Wall_2XuAjyuGzCtwtpth96IVUe20220912151918
# Wall_2XuAjyuGzCtwtpth96IVD320220912151918
# Wall_2XuAjyuGzCtwtpth96IV0920220912151918
# Wall_2XuAjyuGzCtwtpth96IV6I20220912151918
# Wall_2XuAjyuGzCtwtpth96IV$S20220912151918
# Wall_2XuAjyuGzCtwtpth96IVpV20220912151918
# Wall_2XuAjyuGzCtwtpth96IVs720220912151918
# Wall_2XuAjyuGzCtwtpth96IVgU20220912151918
# Wall_2XuAjyuGzCtwtpth96IVZn20220912151918
# Wall_2XuAjyuGzCtwtpth96IUQ020220912151918
# Wall_2XuAjyuGzCtwtpth96IU8X20220912151918
# Wall_2XuAjyuGzCtwtpth96IUvl20220912151918
# Wall_2XuAjyuGzCtwtpth96IU_520220912151918
# Wall_2XuAjyuGzCtwtpth96IUp720220912151918
# Wall_2XuAjyuGzCtwtpth96IUf320220912151918
# Wall_2XuAjyuGzCtwtpth96IUjl20220912151918
# Wall_2XuAjyuGzCtwtpth96IUXC20220912151918
# Wall_2XuAjyuGzCtwtpth96IUa520220912151918
# Wall_2XuAjyuGzCtwtpth96IPTF20220912151918
# Wall_2XuAjyuGzCtwtpth96IPH820220912151918
# Wall_2l24N$9E5B9OKR_ga8QWKg20220912151918
# Clutter_363UO_O893Ogp_qzB5enEt20220912151918
# Wall_0$_ihtJE59AOZ4yBsDYZn320220912151918
# Wall_2YoeOuDc19WeMB3Q3UsUVM20220912151918
# Clutter_1jMAwQq_18S9$s0kGPzeYr20220912151918
# Clutter_1jMAwQq_18S9$s0kGPzeac20220912151918
# Wall_1jMAwQq_18S9$s0kGPzefq20220912151918
# Column_1jMAwQq_18S9$s0kGPzfGy20220912151918
# Wall_1jMAwQq_18S9$s0kGPzfUF20220912151918
# Wall_1JMKmATSr3aPF8DYTlyu4Q20220912151918
# Wall_1JMKmATSr3aPF8DYTlyunB20220912151918
# Wall_1JMKmATSr3aPF8DYTlyunV20220912151918
# Wall_1JMKmATSr3aPF8DYTlyumZ20220912151918
# Wall_1JMKmATSr3aPF8DYTlyumJ20220912151918
# Clutter_1JMKmATSr3aPF8DYTlyus420220912151918
# Wall_1JMKmATSr3aPF8DYTlyury20220912151918
# Wall_3jrMIAP5b8AhGquXvG7fug20220912151918
# Wall_3jrMIAP5b8AhGquXvG7fyq20220912151918
# Wall_3jrMIAP5b8AhGquXvG7fn320220912151918
# Wall_1$SmDyt_f3tg3Hez4UYWc220220912151918
# Wall_3dvuN8n$94rBR_TmHVAuXx20220912151918
# Wall_3dvuN8n$94rBR_TmHVAuYb20220912151918
# Wall_3dvuN8n$94rBR_TmHVAudA20220912151918
# Wall_3dvuN8n$94rBR_TmHVAuhm20220912151918
# Wall_3dvuN8n$94rBR_TmHVAuhO20220912151918
# Wall_3dvuN8n$94rBR_TmHVAurA20220912151918
# Wall_2fZMqayVn1MAAQpyx2KMvk20220912151918
# Wall_2fZMqayVn1MAAQpyx2KMt$20220912151918
# Wall_2fZMqayVn1MAAQpyx2KMrq20220912151918
# Wall_2fZMqayVn1MAAQpyx2KMrr20220912151918
# Wall_2fZMqayVn1MAAQpyx2KNDQ20220912151918
# Wall_1tLWl7TrTCAOsl62NXQnD820220912151918
# Wall_17r1bDSPr2b8cuL9e_Q7Gt20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q7I_20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q7KM20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q7Ml20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q6jq20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q6Wl20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q6a420220912151918
# Wall_17r1bDSPr2b8cuL9e_Q6ci20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q6yA20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q6$820220912151918
# Wall_17r1bDSPr2b8cuL9e_Q6mk20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q6nt20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q6qH20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q6CF20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q6EN20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q6OA20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q6RR20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q6Vy20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q6Jm20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q1gu20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q1XW20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q1bY20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q1dm20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q1z620220912151918
# Wall_17r1bDSPr2b8cuL9e_Q1$320220912151918
# Wall_17r1bDSPr2b8cuL9e_Q1oG20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q1qG20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q18w20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q1Ap20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q1Fs20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q16x20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q17b20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q1QJ20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q1GW20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q1HX20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q1K620220912151918
# Wall_17r1bDSPr2b8cuL9e_Q1Lz20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q0in20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q0la20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q0YK20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q0aw20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q0di20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q0wl20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q0yx20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q0_E20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q0$n20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q0qg20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q0rs20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q08G20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q09s20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q06E20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q0PA20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q0QX20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q0SS20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q0Ux20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q0G_20220912151918
# Wall_17r1bDSPr2b8cuL9e_Q0LQ20220912151918
# Clutter_2oEj3hyNTA8u_hfDqsXqML20220912151918
# Wall_2wTjIcEMr4bhqS70fATp3Q20220912151918
# Wall_2wTjIcEMr4bhqS70fATp9F20220912151918
# Wall_2wTjIcEMr4bhqS70fATpB$20220912151918
# Wall_2wTjIcEMr4bhqS70fATpCG20220912151918
# Wall_2wTjIcEMr4bhqS70fAToq120220912151918
# Wall_2wTjIcEMr4bhqS70fAToxa20220912151918
# Wall_2wTjIcEMr4bhqS70fATo$420220912151918
# Wall_2wTjIcEMr4bhqS70fAToWG20220912151918
# Wall_2wTjIcEMr4bhqS70fATojt20220912151918
# Wall_33nKnes$j6SQIV7M11NXwW20220912151918
# Clutter_33nKnes$j6SQIV7M11NXod20220912151918
# Clutter_1PTiJ9C2DFRRzU7EykPs3v20220912151918
# Clutter_1PTiJ9C2DFRRzU7EykPs7N20220912151918
# Clutter_1PTiJ9C2DFRRzU7EykPsBX20220912151918
# Clutter_1PTiJ9C2DFRRzU7EykPvnT20220912151918
# Clutter_39GYKOQKj2YQHbW1IV_dZD20220912151918
# Wall_39GYKOQKj2YQHbW1IV_djq20220912151918
# Clutter_39GYKOQKj2YQHbW1IV_dfr20220912151918
# Clutter_39GYKOQKj2YQHbW1IV_dgA20220912151918
# Slab_3$ikXW8rfBjv4w7_937T0$20220912151918
# Wall_11kjcizv11NhhhdVrH7gOE20220912151918
# Clutter_11kjcizv11NhhhdVrH7gPA20220912151918
# Wall_11kjcizv11NhhhdVrH7gPn20220912151918
# Clutter_3SMYIjMp19Qgr_m1Rz4aok20220912151918
# Clutter_2qFYFPUdf4yAOBW2PWdVAh20220912151918
# Wall_2qFYFPUdf4yAOBW2PWdV8R20220912151918
# Wall_0pWVCN1Kz1gh8tpyZiV3xt20220912151918
# Slab_1Q8w9sMeH0IeqIKdI3WaJU20220912151918
# Clutter_1ySkpHjIvCeAfZIArX70Lg20220912151918
# Clutter_1ySkpHjIvCeAfZIArX709s20220912151918
# Wall_1ySkpHjIvCeAfZIArX70F120220912151918
# Clutter_1ySkpHjIvCeAfZIArX703y20220912151918
# Slab_2BBAW23AjFa9GUG2gws64R20220912151918
# Slab_2BBAW23AjFa9GUG2gws6zn20220912151918
# Clutter_2BBAW23AjFa9GUG2gws6pL20220912151918
# Clutter_2BBAW23AjFa9GUG2gws6tX20220912151918
# Column_2D6KXUv1bDv9pus8iFZGH620220912151918
# Column_2D6KXUv1bDv9pus8iFZGRl20220912151918
# Column_2D6KXUv1bDv9pus8iFZGTt20220912151918
# Column_2D6KXUv1bDv9pus8iFZG3i20220912151918
# Column_2D6KXUv1bDv9pus8iFZG8M20220912151918
# Column_3H8CdN8w53MB2I9x6zYFkB20220912151918
# Column_3H8CdN8w53MB2I9x6zYFiq20220912151918
# Slab_3H8CdN8w53MB2I9x6zYFjC20220912151918
# Column_3H8CdN8w53MB2I9x6zYEGs20220912151918
# Column_1IFzDlbrn9gP8yAK2zaN9420220912151918
# Column_1IFzDlbrn9gP8yAK2zaN8K20220912151918
# Column_1IFzDlbrn9gP8yAK2zaNBB20220912151918
# Column_1IFzDlbrn9gP8yAK2zaN6S20220912151918
# Column_1IFzDlbrn9gP8yAK2zaNS620220912151918
# Column_2S8a72zD9EH8PCXrs6WkhW20220912151918
# Column_1PjMiF3kvC3PhsZamDdm3H20220912151918
# Slab_1PjMiF3kvC3PhsZamDdmCK20220912151918
# Column_1s9eZUAjv6_f7vn4XQybmg20220912151918
# Column_31z9iOBr91g8kNhEHdw$O120220912151918
# Column_31z9iOBr91g8kNhEHdw$Li20220912151918
# Column_31z9iOBr91g8kNhEHdw$K220220912151918
# Clutter_3wheZQ2MT3Th0g0BoTzyzr20220912151919
# Clutter_3wheZQ2MT3Th0g0BoTzy_Y20220912151919
# Clutter_0ytsfaZDr5s9SqTjY7zLnw20220912151919
# Clutter_0ytsfaZDr5s9SqTjY7zLvX20220912151919
# Slab_00WYQHSRzDowU$OZcuEWcS20220912151919
# Clutter_00WYQHSRzDowU$OZcuE$GA20220912151919
# Column_2FOU8ydo1Dzuk0btkhIr4e20220912151919
# Beam_2FOU8ydo1Dzuk0btkhIr1220220912151919
# Clutter_2dFhccIVf1c9T$USABpA4f20220912151919
# Clutter_2dFhccIVf1c9T$USABpA4h20220912151919
# Clutter_2dFhccIVf1c9T$USABpA7O20220912151919
# Clutter_2dFhccIVf1c9T$USABpAEk20220912151919
# Clutter_2dFhccIVf1c9T$USABpAEe20220912151919
# Clutter_2dFhccIVf1c9T$USABpAEr20220912151919
# Clutter_2dFhccIVf1c9T$USABpAF620220912151919
# Clutter_2dFhccIVf1c9T$USABpAF720220912151919
# Clutter_2dFhccIVf1c9T$USABpAF120220912151919
# Clutter_0DdVGSEfrCfBY2iKT3mvoj20220912151919
# Clutter_3UIWdRHkT3be1RjgknsQbb20220912151919
# Clutter_3dwmi$MzPF8e7JfnptqrU320220912151919
# Clutter_3dwmi$MzPF8e7JfnptqrU520220912151919
# Clutter_2aW2MwiVv57hzecWlCqmtO20220912151919
# Clutter_2aW2MwiVv57hzecWlCqmtP20220912151919
# Clutter_2aW2MwiVv57hzecWlCqmoW20220912151919
# Clutter_2aW2MwiVv57hzecWlCqmoX20220912151919
# Clutter_2aW2MwiVv57hzecWlCqmmZ20220912151919
# Clutter_2aW2MwiVv57hzecWlCqmma20220912151919
# Clutter_2aW2MwiVv57hzecWlCqmAp20220912151919
# Clutter_2aW2MwiVv57hzecWlCqmAq20220912151919
# Clutter_2aW2MwiVv57hzecWlCqm6420220912151919
# Clutter_2aW2MwiVv57hzecWlCqm6520220912151919
# Clutter_12diqGUyb5EvcL8AhxGLsM20220912151919
# Clutter_12diqGUyb5EvcL8AhxGLsN20220912151919
# Clutter_2UZPlOygT6uASn5O4Fg1NF20220912151919
# Clutter_2UZPlOygT6uASn5O4Fg1N120220912151919
# Clutter_2UZPlOygT6uASn5O4Fg1VF20220912151919
# Clutter_2UZPlOygT6uASn5O4Fg1VE20220912151919
# Clutter_2UZPlOygT6uASn5O4Fg1UF20220912151919
# Clutter_2UZPlOygT6uASn5O4Fg1UE20220912151919
# Clutter_2UZPlOygT6uASn5O4Fg1U020220912151919
# Clutter_2UZPlOygT6uASn5O4Fg1U320220912151919
# Clutter_1o$6_fpVnC1A$EVEto5gnZ20220912151919
# Clutter_1o$6_fpVnC1A$EVEto5gnW20220912151919
# Clutter_1o$6_fpVnC1A$EVEto5g_x20220912151919
# Clutter_1o$6_fpVnC1A$EVEto5gwA20220912151919
# Clutter_1o$6_fpVnC1A$EVEto5gwx20220912151919
# Clutter_1o$6_fpVnC1A$EVEto5gwg20220912151919
# Clutter_1o$6_fpVnC1A$EVEto5gwh20220912151919
# Clutter_1o$6_fpVnC1A$EVEto5gwf20220912151919
# Clutter_1o$6_fpVnC1A$EVEto5gwl20220912151919
# Clutter_1o$6_fpVnC1A$EVEto5gwi20220912151919
# Clutter_2JvApyy_f0sPoFW01cH4Yb20220912151919
# Clutter_2JvApyy_f0sPoFW01cH4Yd20220912151919
# Clutter_2JvApyy_f0sPoFW01cH4YY20220912151919
# Clutter_2JvApyy_f0sPoFW01cH4jI20220912151919
# Clutter_2JvApyy_f0sPoFW01cH4g$20220912151919
# Clutter_0RfKlARO12wuoYXfF7cZxK20220912151919
# Clutter_0RfKlARO12wuoYXfF7cZxM20220912151919
# Clutter_0RfKlARO12wuoYXfF7cZxJ20220912151919
# Clutter_0RfKlARO12wuoYXfF7cZxc20220912151919
# Clutter_0RfKlARO12wuoYXfF7cZxX20220912151919
# Clutter_1w1mRYLeD3Jf$KyQRKJpDU20220912151919
# Clutter_1w1mRYLeD3Jf$KyQRKJpD120220912151919
# Clutter_3xwjxSAoPDMOCa2Ie32DWZ20220912151919
# Clutter_3xwjxSAoPDMOCa2Ie32DWY20220912151919
# Clutter_3xwjxSAoPDMOCa2Ie32Dfe20220912151919
# Clutter_3xwjxSAoPDMOCa2Ie32Dfd20220912151919
# Clutter_3xwjxSAoPDMOCa2Ie32CIa20220912151919
# Clutter_3xwjxSAoPDMOCa2Ie32CIZ20220912151919
# Clutter_2iBmXJOFb5swbqBAAOckOQ20220912151919
# Clutter_38f8gg9GHCe8$vLUazdeOD20220912151919
# Clutter_38f8gg9GHCe8$vLUazdeOE20220912151919
# Clutter_2cWVEiZZL5NhocLdeM$8yK20220912151919
# Clutter_2cWVEiZZL5NhocLdeM$8yQ20220912151919
# Clutter_2cWVEiZZL5NhocLdeM$8yP20220912151919
# Clutter_2cWVEiZZL5NhocLdeM$8zs20220912151919
# Clutter_2cWVEiZZL5NhocLdeM$8zt20220912151919
# Slab_2cWVEiZZL5NhocLdeM$8tB20220912151919
# Clutter_0ffNf$_JH0zh3cNXUBPzVQ20220912151919
# Clutter_0vv4_GXpT95uAPfkRCJQZw20220912151919
# Clutter_0vv4_GXpT95uAPfkRCJRz020220912151919
# Clutter_0MuzDvrln2Le1EWkFej$wH20220912151919
# Clutter_0MuzDvrln2Le1EWkFej$w820220912151919
# Clutter_0MuzDvrln2Le1EWkFej$zE20220912151919
# Clutter_0MuzDvrln2Le1EWkFej$r_20220912151919
# Clutter_0MuzDvrln2Le1EWkFej$ry20220912151919
# Clutter_0MuzDvrln2Le1EWkFej$rx20220912151919
# Clutter_0b6pthnHr4UwZsgQeRMVsr20220912151919
# Clutter_0b6pthnHr4UwZsgQeRMVst20220912151919
# Clutter_0b6pthnHr4UwZsgQeRMVss20220912151919
# Clutter_2oQdIbZsDFuvrBJ5UFARzQ20220912151919
# Clutter_2iWkxNvwT52APWe0OrvI5c20220912151919
# Clutter_2iWkxNvwT52APWe0OrvI5b20220912151919
# Clutter_2gclusgabAhP7XcduJM5Uw20220912151919
# Clutter_2gclusgabAhP7XcduJM5Uz20220912151919
# Clutter_0E87LQGqn9EPRaMNt8Np6E20220912151919
# Clutter_0E87LQGqn9EPRaMNt8Np6F20220912151919
# Clutter_0E87LQGqn9EPRaMNt8Np5B20220912151919
# Clutter_0E87LQGqn9EPRaMNt8NpgV20220912151919
# Clutter_0E87LQGqn9EPRaMNt8NpgS20220912151919
# Clutter_0E87LQGqn9EPRaMNt8Npod20220912151919
# Clutter_0E87LQGqn9EPRaMNt8Npob20220912151919
# Clutter_0E87LQGqn9EPRaMNt8Npog20220912151919
# Clutter_1H0QZYTFr81Q5gE8Ab6uNG20220912151919
# Clutter_1H0QZYTFr81Q5gE8Ab6uNE20220912151919
# Slab_3mlcqLrj16wRnQ6HamtSP920220912151919
# Slab_2JoBS2gCr9xgFpWW3Kx4TU20220912151919
# Slab_3_NlqcAaD1S9wsIYeh33RZ20220912151919
# Slab_3tPLkzC7z1QftFpxEQQny420220912151919
# Clutter_32AIn2zlb2ZP514clduob420220912151919
# Clutter_32AIn2zlb2ZP514clduofL20220912151919
# Clutter_32AIn2zlb2ZP514cldupGH20220912151919
# Clutter_35vA$wYIn0nPwzCGMC$KkY20220912151919
# Clutter_35vA$wYIn0nPwzCGMC$Kl_20220912151919
# Clutter_35vA$wYIn0nPwzCGMC$KgK20220912151919
# Clutter_35vA$wYIn0nPwzCGMC$KfW20220912151919
# Clutter_35vA$wYIn0nPwzCGMC$Ksu20220912151919
# Clutter_35vA$wYIn0nPwzCGMC$Km820220912151919
# Clutter_35vA$wYIn0nPwzCGMC$K_I20220912151919
# Clutter_35vA$wYIn0nPwzCGMC$KyT20220912151919
# Clutter_35vA$wYIn0nPwzCGMC$Kxm20220912151919
# Clutter_35vA$wYIn0nPwzCGMC$K7o20220912151919
# Clutter_35vA$wYIn0nPwzCGMC$K5A20220912151919
# Clutter_2pE7tnAZ92XOo_JQ2MtyG$20220912151919
# Clutter_2pE7tnAZ92XOo_JQ2MtyH620220912151919
# Wall_2AJ9FuOrDE1Q8D8P6R_1k020220912151919
# Wall_2AJ9FuOrDE1Q8D8P6R_1l320220912151919
# Wall_2AJ9FuOrDE1Q8D8P6R_1mN20220912151919
# Wall_2AJ9FuOrDE1Q8D8P6R_1my20220912151919
# Wall_2AJ9FuOrDE1Q8D8P6R_1n220220912151919
# Wall_2AJ9FuOrDE1Q8D8P6R_1oc20220912151919
# Clutter_2AJ9FuOrDE1Q8D8P6R_1px20220912151919
# Clutter_2AJ9FuOrDE1Q8D8P6R_1qC20220912151919
# Clutter_2AJ9FuOrDE1Q8D8P6R_1rM20220912151919
# Wall_2AJ9FuOrDE1Q8D8P6R_1s320220912151919
# Clutter_2AJ9FuOrDE1Q8D8P6R_1ut20220912151919
# Clutter_2AJ9FuOrDE1Q8D8P6R_Tff20220912151919
# Wall_34H4gfqbr4uBKNqm1hRwcY20220912151919
# Clutter_2N8RQNXJr0wRXJBB4r4c3Q20220912151919
# Clutter_1OoGI5MCf2qOjM2YuwQuB320220912151919
# Clutter_3yhmVbGQXCqBi4xk6A3_TP20220912151919
# Clutter_3yhmVbGQXCqBi4xk6A3_Ui20220912151919
# Clutter_3yhmVbGQXCqBi4xk6A3_Vn20220912151919
# Clutter_3yhmVbGQXCqBi4xk6A3_Gq20220912151919
# Clutter_25S9bYNF9Ba97UOkNmZ52l20220912151919
# Wall_25S9bYNF9Ba97UOkNmZ53F20220912151919
# Clutter_25S9bYNF9Ba97UOkNmZ50k20220912151919
# Clutter_25S9bYNF9Ba97UOkNmZ50H20220912151919
# Wall_25S9bYNF9Ba97UOkNmZ5_020220912151919
# Clutter_25S9bYNF9Ba97UOkNmZ5yG20220912151919
# Wall_25S9bYNF9Ba97UOkNmZ5wa20220912151919
# Clutter_3uMeXB22z6rfO0VLWycxRB20220912151919
# Clutter_3uMeXB22z6rfO0VLWycx6a20220912151919
# Clutter_3uMeXB22z6rfO0VLWycx6O20220912151919
# Clutter_3uMeXB22z6rfO0VLWycx7I20220912151919
# Clutter_3uMeXB22z6rfO0VLWyc_oS20220912151919
# Clutter_3uMeXB22z6rfO0VLWyc_mL20220912151919
# Clutter_0Kis54bFj5nOXWYUcLXODI20220912151919
# Clutter_0Kis54bFj5nOXWYUcLXODY20220912151919
# Wall_0Kis54bFj5nOXWYUcLXO2m20220912151919
# Clutter_0Kis54bFj5nOXWYUcLXO1z20220912151919
# Clutter_0Kis54bFj5nOXWYUcLXO0c20220912151919
# Wall_2zk05uUIP6LONxxKis0eZ620220912151919
# Clutter_2zk05uUIP6LONxxKis0eYN20220912151919
# Wall_2zk05uUIP6LONxxKis0eXw20220912151919
# Clutter_2zk05uUIP6LONxxKis0eWQ20220912151919
# Clutter_2zk05uUIP6LONxxKis0el320220912151919
# Wall_2zk05uUIP6LONxxKis0eks20220912151919
# Wall_2zk05uUIP6LONxxKis0ejk20220912151919
# Clutter_2zk05uUIP6LONxxKis0egE20220912151919
# Clutter_2zk05uUIP6LONxxKis0efY20220912151919
# Clutter_2zk05uUIP6LONxxKis0etR20220912151919
# Wall_2zk05uUIP6LONxxKis0es220220912151919
# Clutter_3vy4Rbpw9F5hcR0tGhzLUi20220912151919
# Clutter_3vy4Rbpw9F5hcR0tGhzLTh20220912151919
# Clutter_3vy4Rbpw9F5hcR0tGhzLRJ20220912151919
# Wall_3vy4Rbpw9F5hcR0tGhzLOG20220912151919
# Clutter_3vy4Rbpw9F5hcR0tGhzLd320220912151919
# Clutter_3vy4Rbpw9F5hcR0tGhzLc720220912151919
# Clutter_3vy4Rbpw9F5hcR0tGhzLcd20220912151919
# Clutter_3vy4Rbpw9F5hcR0tGhzLbr20220912151919
# Wall_3vy4Rbpw9F5hcR0tGhzLap20220912151919
# Wall_3vy4Rbpw9F5hcR0tGhzLZs20220912151919
# Wall_3vy4Rbpw9F5hcR0tGhzLXD20220912151919
# Wall_3vy4Rbpw9F5hcR0tGhzLWS20220912151919
# Wall_3vy4Rbpw9F5hcR0tGhzLlO20220912151919
# Wall_3vy4Rbpw9F5hcR0tGhzLko20220912151919
# Clutter_3vy4Rbpw9F5hcR0tGhzLi$20220912151919
# Clutter_3vy4Rbpw9F5hcR0tGhzLgz20220912151919
# Wall_3vy4Rbpw9F5hcR0tGhzLfw20220912151919
# Clutter_0Srsxo9abFvgwgh5Z7SLv520220912151919
# Clutter_0Srsxo9abFvgwgh5Z7SLu920220912151919
# Clutter_0Srsxo9abFvgwgh5Z7SLtA20220912151919
# Clutter_0Srsxo9abFvgwgh5Z7SLsO20220912151919
# Clutter_0Srsxo9abFvgwgh5Z7SLsk20220912151919
# Clutter_0Srsxo9abFvgwgh5Z7SLrW20220912151919
# Clutter_0Srsxo9abFvgwgh5Z7SLpS20220912151919
# Clutter_0Srsxo9abFvgwgh5Z7SLoC20220912151919
# Clutter_0Srsxo9abFvgwgh5Z7SLnd20220912151919
# Clutter_0Srsxo9abFvgwgh5Z7SLlO20220912151919
# Clutter_0Srsxo9abFvgwgh5Z7SLkG20220912151919
# Clutter_0Srsxo9abFvgwgh5Z7SLjo20220912151919
# Clutter_0Srsxo9abFvgwgh5Z7SLhw20220912151919
# Clutter_0Srsxo9abFvgwgh5Z7SLfE20220912151919
# Clutter_0Srsxo9abFvgwgh5Z7SLeA20220912151919
# Clutter_0Srsxo9abFvgwgh5Z7SLdy20220912151919
# Clutter_3eIBvNtOT3eP9KMXM4jTZs20220912151919
# Clutter_3eIBvNtOT3eP9KMXM4jTbu20220912151919
# Clutter_3eIBvNtOT3eP9KMXM4jTa720220912151919
# Clutter_3eIBvNtOT3eP9KMXM4jTcJ20220912151919
# Clutter_3eIBvNtOT3eP9KMXM4jTOF20220912151919
# Clutter_3eIBvNtOT3eP9KMXM4jTRb20220912151919
# Clutter_3eIBvNtOT3eP9KMXM4jTTH20220912151919
# Clutter_3eIBvNtOT3eP9KMXM4jTS520220912151919
# Clutter_1MkS6Fx3P0QO_zt8IHSW2Q20220912151919
# Clutter_1MkS6Fx3P0QO_zt8IHSW2z20220912151919
# Clutter_1MkS6Fx3P0QO_zt8IHSWCB20220912151919
# Wall_1MkS6Fx3P0QO_zt8IHSWEL20220912151919
# Clutter_1MkS6Fx3P0QO_zt8IHSWF120220912151919
# Clutter_0GMduEvIr4XBjJg2bcMUjP20220912151919
# Clutter_0GMduEvIr4XBjJg2bcMUls20220912151919
# Clutter_0GMduEvIr4XBjJg2bcMUku20220912151919
# Clutter_0GMduEvIr4XBjJg2bcMUWp20220912151919
# Clutter_0GMduEvIr4XBjJg2bcMUZy20220912151919
# Clutter_0GMduEvIr4XBjJg2bcMUaS20220912151919
# Clutter_0GMduEvIr4XBjJg2bcMUwS20220912151919
# Clutter_0GMduEvIr4XBjJg2bcMUzi20220912151919
# Clutter_3u6gLxhtj2Zu58HVVCp82a20220912151919
# Clutter_3u6gLxhtj2Zu58HVVCp81020220912151919
# Clutter_3u6gLxhtj2Zu58HVVCp86v20220912151919
# Clutter_3u6gLxhtj2Zu58HVVCp84k20220912151919
# Clutter_3u6gLxhtj2Zu58HVVCp85620220912151919
# Clutter_3u6gLxhtj2Zu58HVVCpErt20220912151919
# Clutter_3u6gLxhtj2Zu58HVVCpEgz20220912151919
# Clutter_3u6gLxhtj2Zu58HVVCpEh$20220912151919
# Clutter_3u6gLxhtj2Zu58HVVCpEk920220912151919
# Clutter_3u6gLxhtj2Zu58HVVCpElP20220912151919
# Clutter_3u6gLxhtj2Zu58HVVCpEik20220912151919
# Clutter_3u6gLxhtj2Zu58HVVCpEjs20220912151919
# Clutter_3u6gLxhtj2Zu58HVVCpEZ320220912151919
# Clutter_3u6gLxhtj2Zu58HVVCpEW320220912151919
# Clutter_3u6gLxhtj2Zu58HVVCpEXX20220912151919
# Clutter_3u6gLxhtj2Zu58HVVCpEd020220912151919
# Slab_3zYv5MxfP0OQbmDRo3dLbT20220912151919
# Clutter_3zYv5MxfP0OQbmDRo3dKj_20220912151919
# Slab_3zYv5MxfP0OQbmDRo3dKk_20220912151919
# Clutter_3zYv5MxfP0OQbmDRo3dKW220220912151919
# Clutter_3zYv5MxfP0OQbmDRo3dKZ220220912151919
# Clutter_3zYv5MxfP0OQbmDRo3dKdx20220912151919
# Clutter_3zYv5MxfP0OQbmDRo3dKcG20220912151919
# Clutter_3zYv5MxfP0OQbmDRo3dKcu20220912151919
# Slab_3QFr$YmxTCAetygfNk13aW20220912151919
# Clutter_35J_mi8mn8TPyLS1gx9iRd20220912151919
# Clutter_35J_mi8mn8TPyLS1gx9jCj20220912151919
# Clutter_35J_mi8mn8TPyLS1gx9j3N20220912151919
# Clutter_35J_mi8mn8TPyLS1gx9j1j20220912151919
# Clutter_35J_mi8mn8TPyLS1gx9k5U20220912151919
# Clutter_35J_mi8mn8TPyLS1gx9kPY20220912151919
# Clutter_35J_mi8mn8TPyLS1gx9kUi20220912151919
# Clutter_35J_mi8mn8TPyLS1gx9kUh20220912151919
# Clutter_35J_mi8mn8TPyLS1gx9kTA20220912151919
# Clutter_35J_mi8mn8TPyLS1gx9kHc20220912151919
# Clutter_35J_mi8mn8TPyLS1gx9kXn20220912151919
# Clutter_2fiw4GX1b0NPmZRJkvi09Z20220912151919
# Clutter_2fiw4GX1b0NPmZRJkvi0Bo20220912151919
# Clutter_2fiw4GX1b0NPmZRJkvi0Vk20220912151919
# Clutter_3Os0mhpzrAKvGyC6_8FRGh20220912151919
# Clutter_3Os0mhpzrAKvGyC6_8FRTp20220912151919
# Clutter_3Os0mhpzrAKvGyC6_8FRRw20220912151919
# Clutter_3Os0mhpzrAKvGyC6_8FROv20220912151919
# Clutter_3Os0mhpzrAKvGyC6_8FQZa20220912151919
# Clutter_3Os0mhpzrAKvGyC6_8FQWf20220912151919
# Clutter_3NRS$$hOr7n9wfvpt0oFKv20220912151919
# Clutter_3NRS$$hOr7n9wfvpt0oFKH20220912151919
# Clutter_38yNIK7Cb2UwLuNzDMNYsS20220912151919
# Clutter_38yNIK7Cb2UwLuNzDMNYsT20220912151919
# Slab_17muXLGcDBAONZnfWHGDdF20220912151919
# Column_3jhaNbnxX1kv5vPSU4bn0620220912151919
# Column_3jhaNbnxX1kv5vPSU4bnPQ20220912151919
# Column_3jhaNbnxX1kv5vPSU4bnRS20220912151919
# Column_3n07Vkz9X5fxdSUylp9VTD20220912151919
# Column_10xofLusP9gg_CdMZi51lc20220912151919
# Column_2DyrKZaxb3H837waKJJlFo20220912151919
# Column_1wx$rrgLnCHAJfWfA4GmZS20220912151919
# Column_3z4H6NcrzE6O2thEbzvNYK20220912151919
# Wall_2jZpoxmnr4OevJhgmQzmgE20220912151919
# Wall_27dvz1q5rEi8UBq0mvVems20220912151919
# Wall_27dvz1q5rEi8UBq0mvVerB20220912151919
# Wall_27dvz1q5rEi8UBq0mvVea320220912151919
# Wall_27dvz1q5rEi8UBq0mvVfSu20220912151919
# Wall_27dvz1q5rEi8UBq0mvVfVm20220912151919
# Wall_27dvz1q5rEi8UBq0mvVfJH20220912151919
# Wall_27dvz1q5rEi8UBq0mvVfM_20220912151919
# Wall_27dvz1q5rEi8UBq0mvVf9y20220912151919
# Wall_27dvz1q5rEi8UBq0mvVfAO20220912151919
# Wall_27dvz1q5rEi8UBq0mvVfEv20220912151919
# Wall_27dvz1q5rEi8UBq0mvVf5i20220912151919
# Wall_27dvz1q5rEi8UBq0mvVfuN20220912151919
# Wall_27dvz1q5rEi8UBq0mvVfxk20220912151919
# Wall_27dvz1q5rEi8UBq0mvVfz$20220912151919
# Wall_27dvz1q5rEi8UBq0mvVf$B20220912151919
# Wall_27dvz1q5rEi8UBq0mvVfnZ20220912151919
# Wall_27dvz1q5rEi8UBq0mvVfpW20220912151919
# Wall_27dvz1q5rEi8UBq0mvVfrs20220912151919
# Wall_27dvz1q5rEi8UBq0mvVft220220912151919
# Wall_27dvz1q5rEi8UBq0mvVff720220912151919
# Wall_27dvz1q5rEi8UBq0mvVfhG20220912151919
# Wall_27dvz1q5rEi8UBq0mvVfjP20220912151919
# Wall_27dvz1q5rEi8UBq0mvVfXa20220912151919
# Wall_27dvz1q5rEi8UBq0mvVfZF20220912151919
# Wall_27dvz1q5rEi8UBq0mvVfdl20220912151919
# Wall_27dvz1q5rEi8UBq0mvVcRs20220912151919
# Wall_27dvz1q5rEi8UBq0mvVcT420220912151919
# Wall_27dvz1q5rEi8UBq0mvVcHd20220912151919
# Wall_27dvz1q5rEi8UBq0mvVcJ120220912151919
# Wall_27dvz1q5rEi8UBq0mvVcKV20220912151919
# Wall_27dvz1q5rEi8UBq0mvVcNa20220912151919
# Wall_27dvz1q5rEi8UBq0mvVc9O20220912151919
# Wall_27dvz1q5rEi8UBq0mvVcBN20220912151919
# Wall_27dvz1q5rEi8UBq0mvVcE720220912151919
# Wall_27dvz1q5rEi8UBq0mvVc0L20220912151919
# Wall_27dvz1q5rEi8UBq0mvVc2P20220912151919
# Wall_27dvz1q5rEi8UBq0mvVc6T20220912151919
# Wall_27dvz1q5rEi8UBq0mvVcvU20220912151919
# Wall_27dvz1q5rEi8UBq0mvVcyg20220912151919
# Wall_27dvz1q5rEi8UBq0mvVc$e20220912151919
# Wall_27dvz1q5rEi8UBq0mvVcnv20220912151919
# Wall_27dvz1q5rEi8UBq0mvVcoS20220912151919
# Wall_27dvz1q5rEi8UBq0mvVcqt20220912151919
# Wall_27dvz1q5rEi8UBq0mvVcqC20220912151919
# Wall_27dvz1q5rEi8UBq0mvVctB20220912151919
# Wall_27dvz1q5rEi8UBq0mvVcfW20220912151919
# Wall_27dvz1q5rEi8UBq0mvVcix20220912151919
# Wall_27dvz1q5rEi8UBq0mvVckS20220912151919
# Clutter_27uw4d6$55WeGnhiZxVutq20220912151919
# Clutter_028Wogfqf2uOlshHvygIcw20220912151919
# Clutter_028Wogfqf2uOlshHvygIbc20220912151919
# Clutter_028Wogfqf2uOlshHvygIbv20220912151919
# Clutter_1NdkxyMIL6xghTWuGoz5_K20220912151919
# Clutter_1NdkxyMIL6xghTWuGoz5pz20220912151919
# Clutter_1NdkxyMIL6xghTWuGoz5mS20220912151919
# Clutter_2uaEjfsJr2MwSH9XGIT4rE20220912151919
# Clutter_1G9VQtMcn8_xI04mvR6A3o20220912151919
# Clutter_1G9VQtMcn8_xI04mvR6ADG20220912151919
# Clutter_1G9VQtMcn8_xI04mvR6A9o20220912151919
# Clutter_2jE7CRshzDh9gIJeaulWHy20220912151919
# Clutter_1hAfeeowjEY8ReiSbx_xYE20220912151919
# Clutter_26Hg$KDffF5hTUevrXv96k20220912151919
# Clutter_26Hg$KDffF5hTUevrXv9Or20220912151919
# Clutter_0BVfdUlTPERxvLcnFeI4LA20220912151919
# Clutter_0BVfdUlTPERxvLcnFeI4HO20220912151919
# Clutter_0BVfdUlTPERxvLcnFeI4JP20220912151919
# Clutter_0BVfdUlTPERxvLcnFeI4Eg20220912151919
# Clutter_0BVfdUlTPERxvLcnFeI49T20220912151919
# Clutter_3raToONhrEnvh3Y3TL$uKx20220912151919
# Clutter_1RzPs0PIX71OmF$MNY84bG20220912151919
# Slab_1SrjG9jR9BUx6CLn7jlldJ20220912151919
# Clutter_0l9eTSNPfBTOS8ZMJ134ht20220912151919
# Clutter_0l9eTSNPfBTOS8ZMJ134e$20220912151919
# Clutter_0l9eTSNPfBTOS8ZMJ134fJ20220912151919
# Clutter_0l9eTSNPfBTOS8ZMJ134so20220912151919
# Clutter_0l9eTSNPfBTOS8ZMJ134qD20220912151919
# Clutter_2u$Utk_dz8BuKh0btPtE6j20220912151919
# Wall_0bOlnkW59DjubTltZzGPBz20220912151918
# Wall_0bOlnkW59DjubTltZzGPA520220912151918
# Wall_0bOlnkW59DjubTltZzGPLS20220912151918
# Wall_2I1MjW3CrCRgIwhVTYKkBY20220912151918
# Wall_23Mp1K7OnEufd$s80WXn2n20220912151918
# Wall_23Mp1K7OnEufd$s80WXn5O20220912151918
# Wall_23Mp1K7OnEufd$s80WXn6n20220912151918
# Wall_1P8MczBEH8egptuf62UuwG20220912151918
# Wall_1P8MczBEH8egptuf62Uu_v20220912151918
# Wall_1P8MczBEH8egptuf62UuZk20220912151918
# Wall_1P8MczBEH8egptuf62UubF20220912151918
# Wall_1P8MczBEH8egptuf62Uudb20220912151918
# Wall_1P8MczBEH8egptuf62Uuew20220912151918
# Wall_1P8MczBEH8egptuf62UujN20220912151918
# Wall_1P8MczBEH8egptuf62UuGR20220912151918
# Wall_1P8MczBEH8egptuf62UuMo20220912151918
# Wall_0AYxtLLOP6VuUmxRnPkcCt20220912151918
# Slab_0RfxnmKhnFt8lZZoMYxoyy20220912151918
# Beam_2EM3LFPebAdRGQiZdhxEVg20220912151918
# Beam_2E6MvtfET51OmoF98sGZeH20220912151918
# Beam_1$ttJczm1EyPLEa5xfenDs20220912151918
# Beam_1$ttJczm1EyPLEa5xfenEp20220912151918
# Beam_1$ttJczm1EyPLEa5xfen3W20220912151918
# Beam_1$ttJczm1EyPLEa5xfen3820220912151918
# Beam_1$ttJczm1EyPLEa5xfen5S20220912151918
# Beam_1$ttJczm1EyPLEa5xfen6L20220912151918
# Beam_39x1jfQErBLOMIdxwHajvw20220912151918
# Beam_39x1jfQErBLOMIdxwHajpf20220912151918
# Beam_39x1jfQErBLOMIdxwHajrl20220912151918
# Beam_00dS2W3sLC0g8BCC80seXc20220912151918
# Beam_2diq$TLG93ggBhlsZqNVrB20220912151918
# Beam_2Jvu3vKGH67fafOIAa2vNJ20220912151918
# Beam_2Jvu3vKGH67fafOIAa2vNT20220912151918
# Beam_2Jvu3vKGH67fafOIAa2vFq20220912151918
# Beam_2Jvu3vKGH67fafOIAa2vFs20220912151918
# Beam_0j940eu4LB$f4oPooJqIgi20220912151918
# Beam_0j940eu4LB$f4oPooJqIgk20220912151918
# Beam_0j940eu4LB$f4oPooJqIHz20220912151918
# Beam_0j940eu4LB$f4oPooJqIH$20220912151918
# Beam_0j940eu4LB$f4oPooJqIM420220912151918
# Beam_0j940eu4LB$f4oPooJqIM620220912151918
# Beam_3mCtRULCr3JhZeBXE3vypD20220912151918
# Beam_3mCtRULCr3JhZeBXE3vym820220912151918
# Beam_3mCtRULCr3JhZeBXE3vyx820220912151918
# Beam_3mCtRULCr3JhZeBXE3vyuQ20220912151918
# Wall_15ZpcD58H6wAzEd5s_IHzp20220912151918
# Beam_1gCPLWSeLASR5CjPPTRb0Q20220912151918
# Slab_1Q8qhx57PBHuFnWiJjpW3R20220912151919
# Wall_2meI3thB11jPdVBW7YtWJk20220912151919
# Wall_2meI3thB11jPdVBW7YtWeS20220912151919
# Wall_14Nj4_KxnFRQRWUhgkjEX020220912151919
# Wall_0AQuhJtXX0og9Iah4FROlU20220912151919
# Wall_0AQuhJtXX0og9Iah4FROiN20220912151919
# Clutter_1RwqqH9uL7k94JzCkfM4bK20220912151919
# Clutter_1RwqqH9uL7k94JzCkfM4bN20220912151919
# Clutter_1RwqqH9uL7k94JzCkfM4bd20220912151919
# Clutter_1RwqqH9uL7k94JzCkfM4bc20220912151919
# Clutter_1RwqqH9uL7k94JzCkfM4c420220912151919
# Clutter_3DTOKa6Z1D1R$6ylfKklPF20220912151919
# Clutter_3DTOKa6Z1D1R$6ylfKklPm20220912151919
# Clutter_3DTOKa6Z1D1R$6ylfKkl2R20220912151919
# Clutter_3DTOKa6Z1D1R$6ylfKkl2S20220912151919
# Clutter_3DTOKa6Z1D1R$6ylfKklEV20220912151919
# Clutter_3DTOKa6Z1D1R$6ylfKklE020220912151919
# Clutter_3DTOKa6Z1D1R$6ylfKklFG20220912151919
# Clutter_3DTOKa6Z1D1R$6ylfKklFH20220912151919
# Clutter_3DTOKa6Z1D1R$6ylfKkltx20220912151919
# Clutter_3DTOKa6Z1D1R$6ylfKklty20220912151919
# Clutter_0_R2teeLjB0RpJZhqml37W20220912151919
# Clutter_0_R2teeLjB0RpJZhqml37X20220912151919
# Clutter_0_R2teeLjB0RpJZhqml3BS20220912151919
# Clutter_0_R2teeLjB0RpJZhqml3BT20220912151919
# Clutter_0_R2teeLjB0RpJZhqml38Q20220912151919
# Clutter_0_R2teeLjB0RpJZhqml38R20220912151919
# Clutter_3Zhs2T$Rb3mA2weaOkZtoH20220912151919
# Clutter_3Zhs2T$Rb3mA2weaOkZtoN20220912151919
# Clutter_3Zhs2T$Rb3mA2weaOkZtpG20220912151919
# Slab_2ve_CsU1r0Vg37wbT$BF6m20220912151919
# Slab_2ve_CsU1r0Vg37wbT$BF3u20220912151919
# Wall_1PmwPKj3T9cOETdrYOE8Pr20220912151919
# Wall_1PmwPKj3T9cOETdrYOE8pK20220912151919
# Wall_1PmwPKj3T9cOETdrYOE8$I20220912151919
# Wall_1PmwPKj3T9cOETdrYOE8ev20220912151919
# Clutter_0UFs5eQMTAuvD1KV2UdnJ120220912151919
# Beam_2qkhE3mUn5YgmzknRw_P_e20220912151918
# Beam_2qkhE3mUn5YgmzknRw_Q8s20220912151918
# Beam_2qkhE3mUn5YgmzknRw_QJr20220912151918
# Beam_2qkhE3mUn5YgmzknRw_QJp20220912151918
# Beam_2qkhE3mUn5YgmzknRw_QJk20220912151918
# Beam_2qkhE3mUn5YgmzknRw_QJi20220912151918
# Beam_2qkhE3mUn5YgmzknRw_QG320220912151918
# Beam_2qkhE3mUn5YgmzknRw_QG120220912151918
# Beam_2qkhE3mUn5YgmzknRw_QOk20220912151918
# Beam_2qkhE3mUn5YgmzknRw_QOi20220912151918
# Beam_2e_OiUchnB58a0bHca2CIS20220912151918
# Beam_2e_OiUchnB58a0bHca2CTY20220912151918
# Roof_1N_vppTRr3n8Pvb2fQ2WWQ20220912151918
# Roof_1Xs9BEm_fCEA7wMTVcvTY520220912151918
# Roof_3R6jgW47nFzOVkAHMSmnGj20220912151918
# Roof_3R6jgW47nFzOVkAHMSmkj420220912151918
# Roof_1OXnIPKkv9pQspv2kKU_V$20220912151918
# Roof_3Hf4fQcfP4fBQ$agCVy04P20220912151918
# Roof_0UYb0dUwv5pO5PG$xI_UrB20220912151918
# Roof_0UYb0dUwv5pO5PG$xI_Uqd20220912151918
# Roof_2UQg_3n79AZRRHXKKenjEr20220912151918
# Roof_159O$mByv4ue5wBd7SPcSo20220912151918
# Roof_2E_n7n6FzCJxKeeeoios5020220912151918
# Roof_2RTgz043f1L8xprvdPPt5X20220912151918
# Roof_1EHz9$3iv2cQ$ps4TXh56j20220912151918
# Roof_3eMYTZQvbDmgicZmd6ndxF20220912151918
# Roof_03leHJ4h5DwusS6y1RjBYE20220912151918
# Roof_0hqzO8EfL55BFaZCsNZY3B20220912151918
# Roof_0hqzO8EfL55BFaZCsNZY5x20220912151918
# Roof_2fDML4ozz7rAS4qtASiXg$20220912151918
# Roof_2fDML4ozz7rAS4qtASiXko20220912151918
# Roof_0NtDg_RJr75vYWYZw_kK8U20220912151918
# Roof_2D$w1sdaz4ThOJSWkVDeK620220912151918
# Roof_1clUOhF0H76OigF7SQlzTm20220912151918
# Roof_1ugKlxj9DBTBBnCLcJCG4J20220912151918
# Roof_3cWINNEH9EiPdlK_YPTyBe20220912151918
# Roof_18Pv8$wLv8XOOAKaLtCLQJ20220912151918
# Roof_2GULb9gM1EIu6GRhXaPvGN20220912151918
# Roof_2XDZbbK$T4IBYdzqzyW2js20220912151918
# Roof_3QFE6Qbwn9cwUsgDsfdmyZ20220912151918
# Roof_20p6CnFTz5jBEIFhywfsgV20220912151918
# Roof_0STJrW0a9C4uZYtidDD7Qx20220912151918
# Roof_0bdYQHHxLAVAZ3me3Bprjj20220912151918
# Roof_0dDU$BK4n7gwL7QOC54cTk20220912151918
# Roof_0viVDYXOX8jQqZS7lXgvI120220912151918
# Roof_0Y4Fejzr56h96Ypl4kdi2w20220912151918
# Roof_22QBMNOYD42PmyrHdyQBa320220912151918
# Roof_1qeOYVDXH3uw9RJdbhjHZF20220912151918
# Roof_33d4ErKAXDERV0jhtCUxW420220912151918
# Roof_3oRB9erFTDfRFRKzXUi63520220912151918
# Roof_3oRB9erFTDfRFRKzXUi69d20220912151918
# Roof_2mU7bd6bf6B8f6$dRYJvRA20220912151918
# Roof_3nw9ArWPzBrOwv1DO_dVA320220912151918
# Roof_3nw9ArWPzBrOwv1DO_dVAz20220912151918
# Roof_3nw9ArWPzBrOwv1DO_dVK720220912151918
# Roof_0EiyTHD9L3aQcZXAHYTWyz20220912151918
# Roof_0EiyTHD9L3aQcZXAHYTWwD20220912151918
# Roof_2lGw_Y2JjBSO_BdcbH3iF620220912151918
# Roof_2wbW6EdbD6LuJ0kWvmPpxk20220912151918
# Roof_3y3f50FxX30OAzDc9vM0aM20220912151918
# Roof_0_QzTAPG9EiOOTem8ORk3020220912151918
# Roof_08RzLYYGr76gv91D8co8Dp20220912151918
# Roof_3Xerx5dLP35uvI_QnOOoaM20220912151918
# Roof_2fixwegXjCIQWxE4Ctqc3i20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMtd_20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMtdr20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMtcC20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMtc320220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMtcQ20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMtcG20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMtcc20220912152428
# Roof_2TXbM7mvn9Jfl_1ZCcMtcy20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMtco20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMtb820220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMtbU20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMtbK20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMtbg20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMtbW20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMtbs20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMtaB20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMta120220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMtaN20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMtaj20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMtad20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMtas20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMthA20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMthU20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMthH20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMtht20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMtgA20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMtgT20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMtgK20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMtgg20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMtg$20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMtgu20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMtf920220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMtfU20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMtfJ20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMtfe20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMtfz20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMtfo20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMte720220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMteS20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMtel20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMteY20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMter20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMtl820220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMtlR20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMtlk20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMtlX20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMtlq20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMtk720220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMtkQ20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMtkj20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMtkW20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMtkp20220912151918
# Roof_2TXbM7mvn9Jfl_1ZCcMtj620220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqT720220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqTE20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqSr20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqSy20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqSZ20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqSg20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqSH20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqSO20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqSV20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqS620220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqSD20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqVq20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqVx20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqVY20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqVf20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqVG20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqVN20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqVU20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqV520220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqUp20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqUw20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqUX20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqUe20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqUl20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqUM20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqUT20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqU420220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqUB20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqPo20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqPv20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqPW20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqPd20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqPk20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqPL20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqPS20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqP320220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqPA20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqOn20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqOu20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqO$20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqOc20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqOj20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqOK20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqOR20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqO220220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqO920220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqRm20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqRt20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqR_20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqRb20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqRi20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqRJ20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZqRQ20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtiu20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZti$20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtic20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtij20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtiK20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtiR20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZti220220912151918
# Roof_2mVB9QKlDBTv8_hcSwZti920220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtlm20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtlt20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtl_20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtlb20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtli20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtlJ20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtlQ20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtl120220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtl820220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtlF20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtks20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtky20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtka20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtkh20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtkI20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtkP20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtk020220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtk720220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtkE20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtfr20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtfy20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtfZ20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtfH20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtfO20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtfV20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtf620220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtfD20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZteq20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtex20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZteY20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtef20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZteG20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZteN20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZteU20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZte520220912151918
# Roof_2mVB9QKlDBTv8_hcSwZteC20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZthp20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZthw20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZthX20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZthe20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZthl20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZthM20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZthT20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZth420220912151918
# Roof_2mVB9QKlDBTv8_hcSwZthB20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtyg20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtyH20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtyO20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtyV20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZty620220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtyD20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZt$q20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZt$x20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZt$Y20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZt$f20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZt$G20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZt$N20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZt$U20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZt$520220912151918
# Roof_2mVB9QKlDBTv8_hcSwZt$C20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZt_p20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZt_w20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZt_X20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZt_e20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZt_k20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZt_M20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZt_T20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZt_420220912151918
# Roof_2mVB9QKlDBTv8_hcSwZt_B20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtvo20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtvv20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtvW20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtvd20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtvk20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtvL20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtv320220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtvA20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtun20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtuu20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtu$20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtuc20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtuj20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtuK20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtuR20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtu220220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtu920220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtxm20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtxt20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtx_20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtxb20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtxi20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtxQ20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtx120220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtx820220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtxF20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtws20220912151918
# Roof_2mVB9QKlDBTv8_hcSwZtwz20220912151918
# Roof_07v_zgiYT2Peol9P0UWyxE20220912151918
# Roof_07v_zgiYT2Peol9P0UWyxN20220912151918
# Roof_07v_zgiYT2Peol9P0UWyxO20220912151918
# Roof_07v_zgiYT2Peol9P0UWyxX20220912151918
# Roof_07v_zgiYT2Peol9P0UWyxg20220912151918
# Roof_07v_zgiYT2Peol9P0UWyxp20220912151918
# Roof_07v_zgiYT2Peol9P0UWyxq20220912151918
# Roof_07v_zgiYT2Peol9P0UWyxz20220912151918
# Roof_07v_zgiYT2Peol9P0UWyu620220912151918
# Roof_07v_zgiYT2Peol9P0UWyuF20220912151918
# Roof_07v_zgiYT2Peol9P0UWyuP20220912151918
# Roof_07v_zgiYT2Peol9P0UWyuY20220912151918
# Roof_07v_zgiYT2Peol9P0UWyuh20220912151918
# Roof_07v_zgiYT2Peol9P0UWyui20220912151918
# Roof_07v_zgiYT2Peol9P0UWyur20220912151918
# Roof_07v_zgiYT2Peol9P0UWyu_20220912151918
# Roof_07v_zgiYT2Peol9P0UWyv720220912151918
# Roof_07v_zgiYT2Peol9P0UWyv920220912151918
# Roof_07v_zgiYT2Peol9P0UWyvH20220912151918
# Roof_07v_zgiYT2Peol9P0UWyvQ20220912151918
# Roof_07v_zgiYT2Peol9P0UWyva20220912151918
# Roof_07v_zgiYT2Peol9P0UWyvj20220912151918
# Roof_07v_zgiYT2Peol9P0UWyvs20220912151918
# Roof_07v_zgiYT2Peol9P0UWyv$20220912151918
# Roof_07v_zgiYT2Peol9P0UWy_020220912151918
# Roof_07v_zgiYT2Peol9P0UWy_920220912151918
# Roof_07v_zgiYT2Peol9P0UWy_I20220912151918
# Roof_07v_zgiYT2Peol9P0UWy_R20220912151918
# Roof_07v_zgiYT2Peol9P0UWy_S20220912151918
# Roof_07v_zgiYT2Peol9P0UWy_b20220912151919
# Roof_07v_zgiYT2Peol9P0UWy_k20220912151919
# Roof_07v_zgiYT2Peol9P0UWy_t20220912151919
# Roof_07v_zgiYT2Peol9P0UWy_u20220912151919
# Roof_07v_zgiYT2Peol9P0UWy$120220912151919
# Roof_07v_zgiYT2Peol9P0UWy$A20220912151919
# Roof_07v_zgiYT2Peol9P0UWy$J20220912151919
# Roof_07v_zgiYT2Peol9P0UWy$K20220912151919
# Roof_07v_zgiYT2Peol9P0UWy$T20220912151919
# Roof_07v_zgiYT2Peol9P0UWy$c20220912151919
# Roof_07v_zgiYT2Peol9P0UWy$l20220912151919
# Roof_07v_zgiYT2Peol9P0UWy$m20220912151919
# Roof_07v_zgiYT2Peol9P0UWy$v20220912151919
# Roof_07v_zgiYT2Peol9P0UWyy220220912151919
# Roof_07v_zgiYT2Peol9P0UWyyB20220912151919
# Roof_07v_zgiYT2Peol9P0UWyyC20220912151919
# Roof_07v_zgiYT2Peol9P0UWyyL20220912151919
# Roof_07v_zgiYT2Peol9P0UWyyU20220912151919
# Roof_07v_zgiYT2Peol9P0UWyyd20220912151919
# Roof_07v_zgiYT2Peol9P0UWyye20220912151919
# Roof_07v_zgiYT2Peol9P0UWyyn20220912151919
# Roof_07v_zgiYT2Peol9P0UWyyw20220912151919
# Roof_07v_zgiYT2Peol9P0UWz0M20220912151919
# Roof_07v_zgiYT2Peol9P0UWz0V20220912151919
# Roof_07v_zgiYT2Peol9P0UWz0W20220912151919
# Roof_07v_zgiYT2Peol9P0UWz0f20220912151919
# Roof_07v_zgiYT2Peol9P0UWz0o20220912151919
# Roof_07v_zgiYT2Peol9P0UWz0x20220912151919
# Roof_07v_zgiYT2Peol9P0UWz0y20220912151919
# Roof_07v_zgiYT2Peol9P0UWz1520220912151919
# Roof_07v_zgiYT2Peol9P0UWz1E20220912151919
# Roof_07v_zgiYT2Peol9P0UWz1N20220912151919
# Roof_07v_zgiYT2Peol9P0UWz1O20220912151919
# Roof_07v_zgiYT2Peol9P0UWz1X20220912151919
# Roof_07v_zgiYT2Peol9P0UWz1g20220912151919
# Roof_07v_zgiYT2Peol9P0UWz1p20220912151919
# Roof_07v_zgiYT2Peol9P0UWz1q20220912151919
# Roof_07v_zgiYT2Peol9P0UWz1z20220912151919
# Roof_07v_zgiYT2Peol9P0UWz6620220912151919
# Roof_07v_zgiYT2Peol9P0UWz6F20220912151919
# Roof_07v_zgiYT2Peol9P0UWz6G20220912151919
# Roof_07v_zgiYT2Peol9P0UWz6Q20220912151919
# Roof_07v_zgiYT2Peol9P0UWz6Y20220912151919
# Roof_07v_zgiYT2Peol9P0UWz6h20220912151919
# Roof_07v_zgiYT2Peol9P0UWz6i20220912151919
# Roof_07v_zgiYT2Peol9P0UWz6r20220912151919
# Roof_07v_zgiYT2Peol9P0UWz6_20220912151919
# Roof_07v_zgiYT2Peol9P0UWz7720220912151919
# Roof_07v_zgiYT2Peol9P0UWz7820220912151919
# Roof_07v_zgiYT2Peol9P0UWz7H20220912151919
# Roof_07v_zgiYT2Peol9P0UWz7Q20220912151919
# Roof_07v_zgiYT2Peol9P0UWz7Z20220912151919
# Roof_07v_zgiYT2Peol9P0UWz7a20220912151919
# Roof_07v_zgiYT2Peol9P0UWz7j20220912151919
# Roof_07v_zgiYT2Peol9P0UWz7s20220912151919
# Roof_07v_zgiYT2Peol9P0UWz7$20220912151919
# Roof_07v_zgiYT2Peol9P0UWz4020220912151919
# Roof_07v_zgiYT2Peol9P0UWz4920220912151919
# Roof_07v_zgiYT2Peol9P0UWz4I20220912151919
# Roof_07v_zgiYT2Peol9P0UWz4R20220912151919
# Roof_07v_zgiYT2Peol9P0UWz4S20220912151919
# Roof_07v_zgiYT2Peol9P0UWz4b20220912151919
# Roof_07v_zgiYT2Peol9P0UWz4k20220912151919
# Roof_07v_zgiYT2Peol9P0UWz4t20220912151919
# Roof_07v_zgiYT2Peol9P0UWz4u20220912151919
# Roof_07v_zgiYT2Peol9P0UWz5120220912151919
# Roof_07v_zgiYT2Peol9P0UWz5A20220912151919
# Roof_07v_zgiYT2Peol9P0UWz5J20220912151919
# Roof_07v_zgiYT2Peol9P0UWz5K20220912151919
# Roof_07v_zgiYT2Peol9P0UWz5T20220912151919
# Roof_07v_zgiYT2Peol9P0UWz5c20220912151919
# Roof_07v_zgiYT2Peol9P0UWz5l20220912151919
# Roof_07v_zgiYT2Peol9P0UWz5m20220912151919
# Roof_07v_zgiYT2Peol9P0UWz5v20220912151919
# Roof_07v_zgiYT2Peol9P0UWzA220220912151919
# Roof_07v_zgiYT2Peol9P0UWzAB20220912151919
# Roof_07v_zgiYT2Peol9P0UWzB$20220912151919
# Roof_07v_zgiYT2Peol9P0UWz8020220912151919
# Roof_07v_zgiYT2Peol9P0UWz8920220912151919
# Roof_07v_zgiYT2Peol9P0UWz8I20220912151919
# Roof_07v_zgiYT2Peol9P0UWz8R20220912151919
# Roof_07v_zgiYT2Peol9P0UWz8S20220912151919
# Roof_07v_zgiYT2Peol9P0UWz8b20220912151919
# Roof_07v_zgiYT2Peol9P0UWz8k20220912151919
# Roof_07v_zgiYT2Peol9P0UWz8t20220912151919
# Roof_07v_zgiYT2Peol9P0UWz8u20220912151919
# Roof_07v_zgiYT2Peol9P0UWz9120220912151919
# Roof_07v_zgiYT2Peol9P0UWz9A20220912151919
# Roof_07v_zgiYT2Peol9P0UWz9J20220912151919
# Roof_07v_zgiYT2Peol9P0UWz9K20220912151919
# Roof_07v_zgiYT2Peol9P0UWz9T20220912151919
# Roof_07v_zgiYT2Peol9P0UWz9c20220912151919
# Roof_07v_zgiYT2Peol9P0UWz9l20220912151919
# Roof_07v_zgiYT2Peol9P0UWz9m20220912151919
# Roof_07v_zgiYT2Peol9P0UWz9v20220912151919
# Roof_07v_zgiYT2Peol9P0UWzE320220912151919
# Roof_07v_zgiYT2Peol9P0UWzEB20220912151919
# Roof_07v_zgiYT2Peol9P0UWzEC20220912151919
# Roof_07v_zgiYT2Peol9P0UWzEL20220912151919
# Roof_07v_zgiYT2Peol9P0UWzEU20220912151919
# Roof_07v_zgiYT2Peol9P0UWzEd20220912151919
# Roof_07v_zgiYT2Peol9P0UWzEe20220912151919
# Roof_07v_zgiYT2Peol9P0UWzEn20220912151919
# Roof_07v_zgiYT2Peol9P0UWzEw20220912151919
# Roof_07v_zgiYT2Peol9P0UWzF320220912151919
# Roof_07v_zgiYT2Peol9P0UWzF420220912151919
# Roof_07v_zgiYT2Peol9P0UWzFM20220912151919
# Roof_07v_zgiYT2Peol9P0UWzFV20220912151919
# Roof_07v_zgiYT2Peol9P0UWzFW20220912151919
# Roof_07v_zgiYT2Peol9P0UWzFf20220912151919
# Roof_07v_zgiYT2Peol9P0UWzFo20220912151919
# Roof_07v_zgiYT2Peol9P0UWzFx20220912151919
# Roof_07v_zgiYT2Peol9P0UWzFy20220912151919
# Roof_07v_zgiYT2Peol9P0UWzC520220912151919
# Roof_07v_zgiYT2Peol9P0UWzCE20220912151919
# Roof_07v_zgiYT2Peol9P0UWzCN20220912151919
# Roof_07v_zgiYT2Peol9P0UWzCO20220912151919
# Roof_07v_zgiYT2Peol9P0UWzCX20220912151919
# Roof_07v_zgiYT2Peol9P0UWzCg20220912151919
# Roof_07v_zgiYT2Peol9P0UWzCp20220912151919
# Roof_07v_zgiYT2Peol9P0UWzCq20220912151919
# Roof_07v_zgiYT2Peol9P0UWzCz20220912151919
# Roof_07v_zgiYT2Peol9P0UWzD620220912151919
# Roof_07v_zgiYT2Peol9P0UWzDF20220912151919
# Roof_07v_zgiYT2Peol9P0UWzDG20220912151919
# Roof_07v_zgiYT2Peol9P0UWzDP20220912151919
# Roof_07v_zgiYT2Peol9P0UWzDY20220912151919
# Roof_07v_zgiYT2Peol9P0UWzDh20220912151919
# Roof_07v_zgiYT2Peol9P0UWzDi20220912151919
# Roof_0uIWEs8D18xQ_MV8SLpBup20220912151919
# Roof_1lsMA1LtfEowRuLULM1Idb20220912151919
# Roof_0VVxVzevv6Txq7pO7AD_3d20220912151919
# Roof_0OMUbNkOX3seE6Ckkrb1Sy20220912151919
# Roof_15JDS79RnElxJ_tpz8yiPJ20220912151919
# Roof_0Lpu9D$gb5hv0uLk6eaXQx20220912151919
# Roof_2h3v4TIm96y9fDOhgpXU4Z20220912151919
# Roof_2h3v4TIm96y9fDOhgpXU4u20220912151919
# Roof_2h3v4TIm96y9fDOhgpXU4n20220912151919
# Roof_2h3v4TIm96y9fDOhgpXU4s20220912151919
# Roof_2h3v4TIm96y9fDOhgpXU4F20220912151919
# Roof_2h3v4TIm96y9fDOhgpXU4420220912151919
# Roof_2h3v4TIm96y9fDOhgpXU4T20220912151919
# Roof_2h3v4TIm96y9fDOhgpXU4I20220912151919
# Roof_2h3v4TIm96y9fDOhgpXU5h20220912151919
# Roof_2h3v4TIm96y9fDOhgpXU5W20220912151919
# Roof_2h3v4TIm96y9fDOhgpXU5v20220912151919
# Roof_2h3v4TIm96y9fDOhgpXU5_20220912151919
# Roof_2h3v4TIm96y9fDOhgpXU5t20220912151919
# Roof_2h3v4TIm96y9fDOhgpXU5C20220912151919
# Roof_2h3v4TIm96y9fDOhgpXU5520220912151919
# Roof_2h3v4TIm96y9fDOhgpXU5Q20220912151919
# Roof_2h3v4TIm96y9fDOhgpXU5J20220912151919
# Roof_2h3v4TIm96y9fDOhgpXU6e20220912151919
# Roof_2h3v4TIm96y9fDOhgpXU6X20220912151919
# Roof_2h3v4TIm96y9fDOhgpXU6c20220912151919
# Roof_2h3v4TIm96y9fDOhgpXU6$20220912151919
# Roof_2h3v4TIm96y9fDOhgpXU6q20220912151919
# Roof_2h3v4TIm96y9fDOhgpXU6D20220912151919
# Roof_2h3v4TIm96y9fDOhgpXU6220220912151919
# Roof_2h3v4TIm96y9fDOhgpXU6R20220912151919
# Roof_2h3v4TIm96y9fDOhgpXU6G20220912151919
# Roof_2h3v4TIm96y9fDOhgpXU7f20220912151919
# Roof_2h3v4TIm96y9fDOhgpXU7T20220912151919
# Roof_26M3un7g57nBC12dSqJD_220220912151919
# Roof_26M3un7g57nBC12dSqJD_T20220912151919
# Roof_26M3un7g57nBC12dSqJD_K20220912151919
# Roof_26M3un7g57nBC12dSqJDzl20220912151919
# Roof_26M3un7g57nBC12dSqJDzc20220912151919
# Roof_26M3un7g57nBC12dSqJDzX20220912151919
# Roof_26M3un7g57nBC12dSqJDzu20220912151919
# Roof_26M3un7g57nBC12dSqJDzp20220912151919
# Roof_26M3un7g57nBC12dSqJDzA20220912151919
# Roof_26M3un7g57nBC12dSqJDz520220912151919
# Roof_26M3un7g57nBC12dSqJDzS20220912151919
# Roof_26M3un7g57nBC12dSqJDzN20220912151919
# Roof_26M3un7g57nBC12dSqJDyk20220912151919
# Roof_26M3un7g57nBC12dSqJDyf20220912151919
# Roof_26M3un7g57nBC12dSqJDyW20220912151919
# Roof_26M3un7g57nBC12dSqJDyx20220912151919
# Roof_26M3un7g57nBC12dSqJDyo20220912151919
# Roof_26M3un7g57nBC12dSqJDyD20220912151919
# Roof_26M3un7g57nBC12dSqJDy420220912151919
# Roof_26M3un7g57nBC12dSqJDyU20220912151919
# Roof_26M3un7g57nBC12dSqJDyM20220912151919
# Roof_26M3un7g57nBC12dSqJDyH20220912151919
# Roof_26M3un7g57nBC12dSqJDpe20220912151919
# Roof_26M3un7g57nBC12dSqJDpZ20220912151919
# Roof_26M3un7g57nBC12dSqJDpw20220912151919
# Roof_26M3un7g57nBC12dSqJDpr20220912151919
# Roof_26M3un7g57nBC12dSqJDpC20220912151919
# Roof_26M3un7g57nBC12dSqJDol20220912151919
# Roof_0MiDlio6zEFfqJLHAJXrC620220912151919
# Roof_0MiDlio6zEFfqJLHAJXrCF20220912151919
# Roof_0MiDlio6zEFfqJLHAJXrCK20220912151919
# Roof_0MiDlio6zEFfqJLHAJXrCT20220912151919
# Roof_0MiDlio6zEFfqJLHAJXrCY20220912151919
# Roof_0MiDlio6zEFfqJLHAJXrCh20220912151919
# Roof_0MiDlio6zEFfqJLHAJXrCm20220912151919
# Roof_0MiDlio6zEFfqJLHAJXrCv20220912151919
# Roof_0MiDlio6zEFfqJLHAJXrC_20220912151919
# Roof_0MiDlio6zEFfqJLHAJXrD720220912151919
# Roof_0MiDlio6zEFfqJLHAJXrDC20220912151919
# Roof_0MiDlio6zEFfqJLHAJXrDL20220912151919
# Roof_0MiDlio6zEFfqJLHAJXrDQ20220912151919
# Roof_0MiDlio6zEFfqJLHAJXrDZ20220912151919
# Roof_0MiDlio6zEFfqJLHAJXrDe20220912151919
# Roof_0MiDlio6zEFfqJLHAJXrDn20220912151919
# Roof_0MiDlio6zEFfqJLHAJXrDs20220912151919
# Roof_0MiDlio6zEFfqJLHAJXrD$20220912151919
# Roof_0MiDlio6zEFfqJLHAJXr2420220912151919
# Roof_0MiDlio6zEFfqJLHAJXr2D20220912151919
# Roof_0MiDlio6zEFfqJLHAJXr2I20220912151919
# Roof_0MiDlio6zEFfqJLHAJXr2R20220912151919
# Roof_0MiDlio6zEFfqJLHAJXr2W20220912151919
# Roof_0MiDlio6zEFfqJLHAJXr2f20220912151919
# Roof_0MiDlio6zEFfqJLHAJXr2k20220912151919
# Roof_0MiDlio6zEFfqJLHAJXr2t20220912151919
# Roof_0MiDlio6zEFfqJLHAJXr2y20220912151919
# Roof_0MiDlio6zEFfqJLHAJXr3520220912151919
# Roof_07ncYt6Zf5swWRKOYKfHFW20220912151919
# Roof_07ncYt6Zf5swWRKOYKfHFh20220912151919
# Roof_07ncYt6Zf5swWRKOYKfH8I20220912151919
# Roof_07ncYt6Zf5swWRKOYKfH8S20220912151919
# Roof_07ncYt6Zf5swWRKOYKfH8720220912151919
# Roof_07ncYt6Zf5swWRKOYKfH8E20220912151919
# Roof_07ncYt6Zf5swWRKOYKfH8920220912151919
# Roof_07ncYt6Zf5swWRKOYKfH8m20220912151919
# Roof_07ncYt6Zf5swWRKOYKfH8x20220912151919
# Roof_07ncYt6Zf5swWRKOYKfH8Y20220912151919
# Roof_07ncYt6Zf5swWRKOYKfH8j20220912151919
# Roof_07ncYt6Zf5swWRKOYKfH9K20220912151919
# Roof_07ncYt6Zf5swWRKOYKfH9V20220912151919
# Roof_07ncYt6Zf5swWRKOYKfH9620220912151919
# Roof_07ncYt6Zf5swWRKOYKfH9120220912151919
# Roof_07ncYt6Zf5swWRKOYKfH9820220912151919
# Roof_07ncYt6Zf5swWRKOYKfH9p20220912151919
# Roof_07ncYt6Zf5swWRKOYKfH9w20220912151919
# Roof_07ncYt6Zf5swWRKOYKfH9l20220912151919
# Roof_07ncYt6Zf5swWRKOYKfHAN20220912151919
# Roof_07ncYt6Zf5swWRKOYKfHAU20220912151919
# Roof_07ncYt6Zf5swWRKOYKfHA020220912151919
# Roof_07ncYt6Zf5swWRKOYKfHAB20220912151919
# Roof_07ncYt6Zf5swWRKOYKfHAo20220912151919
# Roof_07ncYt6Zf5swWRKOYKfHAz20220912151919
# Roof_07ncYt6Zf5swWRKOYKfHAa20220912151919
# Beam_3wevYdOgn9yPQJgDAUfosj20220912151919
# Wall_3wevYdOgn9yPQJgDAUfrOv20220912151919
# Wall_3wevYdOgn9yPQJgDAUfrMK20220912151919
# Wall_37m2tGTgv1X95XvDKJOm9t20220912151919
# Clutter_37m2tGTgv1X95XvDKJOmBO20220912151919
# Roof_37m2tGTgv1X95XvDKJOmDe20220912151919
# Clutter_2NH3j6_Ov2FePCy9rf3dp420220912151919
# Clutter_2NH3j6_Ov2FePCy9rf3dp720220912151919
# Clutter_2NH3j6_Ov2FePCy9rf3de520220912151919
# Clutter_3$Njm_GKj9nuLOB91z2VGm20220912151919
# Wall_3$Njm_GKj9nuLOB91z2VvH20220912151919
# Clutter_2f4BMEkRr0RfFf6fveuHTK20220912151919
# Clutter_2f4BMEkRr0RfFf6fveuHTl20220912151919
# Clutter_3wzmHcrcHB98eipLUOzX6820220912151919
# Slab_3wzmHcrcHB98eipLUOzXRA20220912151919
# Beam_3wzmHcrcHB98eipLUOzXVw20220912151919
# Slab_3wzmHcrcHB98eipLUOzXi420220912151919
# Roof_3VRbLtppD5cQ$rSeFGDZD020220912151919
# Roof_3VRbLtppD5cQ$rSeFGDZBQ20220912151919
# Roof_3VRbLtppD5cQ$rSeFGDZr620220912151919
# Roof_3VRbLtppD5cQ$rSeFGDZrd20220912151919
# Roof_3VRbLtppD5cQ$rSeFGDZsB20220912151919
# Roof_3VRbLtppD5cQ$rSeFGDZtT20220912151919
# Roof_3VRbLtppD5cQ$rSeFGDZ$Y20220912151919
# Roof_33bpljmSj7yxd67Q4MAOLK20220912151919
# Roof_33bpljmSj7yxd67Q4MAOJW20220912151919
# Beam_1q_6RjksP86Qle81bIJCrX20220912151919
# Roof_3untf2vXr3BuGc$iuOFNoD20220912151919
# Roof_3untf2vXr3BuGc$iuOFNnd20220912151919
# Roof_1KVozzEaT5yhnPX7QvBGlS20220912151919
# Roof_1KVozzEaT5yhnPX7QvBGkn20220912151919
# Roof_1KVozzEaT5yhnPX7QvBGeJ20220912151919
# Roof_1KVozzEaT5yhnPX7QvBGhA20220912151919
# Roof_1KVozzEaT5yhnPX7QvBGbM20220912151919
# Roof_1KVozzEaT5yhnPX7QvBGak20220912151919
# Roof_02NgvEvUj9QhNhO$YhcV$020220912151919
# Roof_3HpDHtn$XAsBeCUvDzZiRm20220912151919
# Roof_2PMCU7iTP2WAa22Y7zZMT420220912151919
# Roof_2PMCU7iTP2WAa22Y7zZMMq20220912151919
# Roof_2PMCU7iTP2WAa22Y7zZMHz20220912151919
# Roof_38F_Pb5cbDjQ3uitj$Y1NM20220912151919
# Roof_38F_Pb5cbDjQ3uitj$Y2ek20220912151919
# Roof_38F_Pb5cbDjQ3uitj$Y2gd20220912151919
# Roof_38F_Pb5cbDjQ3uitj$Y2iD20220912151919
# Roof_2EuJz3uAj3Q9nncoo543kk20220912151919
# Roof_0nviA1QkL7O8z1t$YC9wGR20220912151919
# Roof_0nviA1QkL7O8z1t$YC9wNr20220912151919
# Roof_0nviA1QkL7O8z1t$YC9wAX20220912151919
# Roof_0nviA1QkL7O8z1t$YC9w8L20220912151919
# Roof_0nviA1QkL7O8z1t$YC9wEm20220912151919
# Roof_0nviA1QkL7O8z1t$YC9wFQ20220912151919
# Roof_0nviA1QkL7O8z1t$YC9wCK20220912151919
# Roof_0nviA1QkL7O8z1t$YC9wD320220912151919
# Roof_3$dBGEgUbDhPz7oP4Nrqcd20220912151919
# Roof_3$dBGEgUbDhPz7oP4Nrqc320220912151919
# Roof_1t3qfZMbD3muIbBq22$nOP20220912151919
# Roof_0P9XiY4xf1jODitX8wtyst20220912151919
# Roof_0P9XiY4xf1jODitX8wtyru20220912151919
# Roof_0P9XiY4xf1jODitX8wtyC120220912151919
# Wall_2UqnVhpsLFRvF8rQoU_9LB20220912151919
# Wall_2UqnVhpsLFRvF8rQoU_9_m20220912151919
# Wall_2UqnVhpsLFRvF8rQoU_9rq20220912151919
# Wall_2UqnVhpsLFRvF8rQoU_9tz20220912151919
# Wall_2UqnVhpsLFRvF8rQoU_9fF20220912151919
# Clutter_2xMu$FO51EABwCYEirz$aQ20220912151919
# Clutter_2Kel5cozH2S85Shkumk27f20220912151919
# Clutter_2Kel5cozH2S85Shkumk2A120220912151919
# Clutter_2axtN9_lLFhPQBvMTnasMc20220912151919
# Clutter_09OYBDjK91CuB2iWK3Zq6d20220912151919
# Clutter_09OYBDjK91CuB2iWK3Zq7l20220912151919
# Clutter_09OYBDjK91CuB2iWK3Zq5520220912151919
# Clutter_09OYBDjK91CuB2iWK3Zq5n20220912151919
# Clutter_09OYBDjK91CuB2iWK3Zq2r20220912151919
# Clutter_09OYBDjK91CuB2iWK3Zq0c20220912151919
# Clutter_09OYBDjK91CuB2iWK3ZqET20220912151919
# Clutter_09OYBDjK91CuB2iWK3ZqEb20220912151919
# Clutter_1cdhWX7ij3j8PXzD0a89n420220912151919
# Clutter_1cdhWX7ij3j8PXzD0a89m720220912151919
# Clutter_2jxa$FMzv5pPbHrL2fuyx620220912151919
# Clutter_2jxa$FMzv5pPbHrL2fuyuk20220912151919
# Clutter_2_XsRs$UTAsAIfk5jcGVBT20220912151919
# Clutter_30GhL9c052jeLwQva58AvW20220912151919
# Clutter_1w6LEvde9CiOd_tSc$Injy20220912151919
# Clutter_0Ua6AMYpDDs8w4fkJ3CNMa20220912151919
# Clutter_0Ua6AMYpDDs8w4fkJ3CNGl20220912151919
# Clutter_0Ua6AMYpDDs8w4fkJ3CNIV20220912151919
# Clutter_0Ua6AMYpDDs8w4fkJ3CNDk20220912151919
# Clutter_0Ua6AMYpDDs8w4fkJ3CNEZ20220912151919
# Clutter_0Ua6AMYpDDs8w4fkJ3CNFj20220912151919
# Clutter_0Ua6AMYpDDs8w4fkJ3CN8d20220912151919
# Clutter_0Ua6AMYpDDs8w4fkJ3CN8320220912151919
# Clutter_0Ua6AMYpDDs8w4fkJ3CNAF20220912151919
# Clutter_0Ua6AMYpDDs8w4fkJ3CNBw20220912151919
# Clutter_1Q95rfBLfFgxDPi2Q$UAYf20220912151919
# Clutter_1Q95rfBLfFgxDPi2Q$UAXg20220912151919
# Clutter_3VitacKnvFEANlLibxI9hE20220912151919
# Clutter_3VitacKnvFEANlLibxI9h_20220912151919
# Clutter_3VitacKnvFEANlLibxI9gv20220912151919
# Clutter_3VitacKnvFEANlLibxI9fk20220912151919
# Clutter_3VitacKnvFEANlLibxI9bM20220912151919
# Clutter_3VitacKnvFEANlLibxI9bd20220912151919
# Clutter_3VitacKnvFEANlLibxI9aL20220912151919
# Clutter_08HrDmV_HFzAZ0USsSMNHs20220912151919
# Clutter_08HrDmV_HFzAZ0USsSMNi820220912151919
# Clutter_08HrDmV_HFzAZ0USsSMNXS20220912151919
# Clutter_08HrDmV_HFzAZ0USsSMNaB20220912151919
# Clutter_08HrDmV_HFzAZ0USsSMNbg20220912151919
# Clutter_08HrDmV_HFzAZ0USsSMNbB20220912151919
# Clutter_08HrDmV_HFzAZ0USsSMNya20220912151919
# Clutter_08HrDmV_HFzAZ0USsSMNza20220912151919
# Clutter_3dcS9f$gHFF9ZAEjKAAed720220912151919
# Clutter_3dcS9f$gHFF9ZAEjKAAear20220912151919
# Clutter_3dcS9f$gHFF9ZAEjKAAeaD20220912151919
# Clutter_3dcS9f$gHFF9ZAEjKAAfVK20220912151919
# Clutter_0Vz6z_ZqD3A8B$yApvAn6g20220912151919
# Clutter_2MpaIGXCX76gxgo4hMoXL520220912151919
# Clutter_2MpaIGXCX76gxgo4hMoXFh20220912151919
# Clutter_2MpaIGXCX76gxgo4hMoX6p20220912151919
# Clutter_0320xJpPfAAeTrp72qJvtT20220912151919
# Clutter_0320xJpPfAAeTrp72qJvtQ20220912151919
# Clutter_0320xJpPfAAeTrp72qJvF920220912151919
# Clutter_0320xJpPfAAeTrp72qJv4320220912151919
# Clutter_0320xJpPfAAeTrp72qJvO$20220912151919
# Clutter_0320xJpPfAAeTrp72qJvPb20220912151919
# Clutter_0320xJpPfAAeTrp72qJvUy20220912151919
# Clutter_0320xJpPfAAeTrp72qJvV$20220912151919
# Clutter_2tXjRYCLz9zeRCuhs4LTMq20220912151919
# Clutter_1MKwvOKd19Dhqn$Yz_pN7x20220912151919
# Clutter_14chYiDur4EedkBn$aDgS020220912151919
# Clutter_14chYiDur4EedkBn$aDhix20220912151919
# Clutter_3EubuJWUv9EAb3JEfcTEAH20220912151919
# Clutter_3EubuJWUv9EAb3JEfcTEmN20220912151919
# Clutter_2FSrMyVrfCde5Q331Z7Ibd20220912151919
# Clutter_2FSrMyVrfCde5Q331Z7TIJ20220912151919
# Clutter_2FSrMyVrfCde5Q331Z7TKF20220912151919
# Clutter_0QhiekpVzAjhb4jixFwjTp20220912151919
# Roof_0JrrCe4YnCNBusl137tFGY20220912151919
# Roof_14tPixhaP9Xud6i2F$KQVd20220912151919
# Roof_3wevYdOgn9yPQJgDAUfr8220220912151919
# Roof_1ObDrGFdH8TR9DchLz1PoQ20220912151919
# Roof_3$Njm_GKj9nuLOB91z2V8T20220912151919
# Roof_3$Njm_GKj9nuLOB91z2V5Q20220912151919
# Roof_2f4BMEkRr0RfFf6fveuH1h20220912151919

# %%
# succes = 0
# for n in sn.bimNodes:
#     try:
#         # print(n.overviewImagePath)
#         succes +=1
#     except: 
#         pass
#         # print("FAILED)")
# print(succes)

# %% [markdown]
# ## Processing of the pointcloud data

# %% [markdown]
# 1. Crop the BIM elements from a point cloud using their expanded BoundingBoxes

# %%
# def create_croppedpcd(pointcloud: PointCloudNode, element: BIMNode, bb: o3d.geometry.OrientedBoundingBox, sn : SessionNode) -> PointCloudNode:
#     """Crops a part of a point cloud around a BIM object.

#     Args:
#         pointcloud (PointCloudNode): Pointcloud from which the zone needs to be cropped
#         element (BIMNode): The BIMNode that the cropped region represents
#         bb (o3d.geometry.OrientedBoundingBox): The boundingbox that needs to be cropped from the pointcloud
#         samplesize (Optional float): When the results needs to be downsampled.
            
#     Returns:
#         PointCloudNode containing the pointcloud of the cropped region
#     """
#     myCroppedPCD=pointcloud.resource.crop(bb)
#     if len(np.asarray(myCroppedPCD.points)) > 0:
#         if sn.resolution and len(np.asarray(myCroppedPCD.points)) >= 1000:
#             myCroppedPCD = myCroppedPCD.voxel_down_sample(sn.resolution)
        
#         try:
#             myCroppedPCDNode=PointCloudNode(resource=myCroppedPCD,
#                                         name = element.get_name().split("-")[0] + "-CROPPEDPCD",
#                                         subject=element.get_name().split("-")[0] + "-CROPPEDPCD",
#                                         isDerivedFromGeometry=pointcloud.subject,
#                                         processed = False)
#             myCroppedPCDNode.save_resource(sn.projectProcessingPath)
#             return myCroppedPCDNode
        
#         except:
#             return None
#     else:
#         return None

# def add_to_croppedpcd(pointcloud: PointCloudNode, element: BIMNode, target: PointCloudNode ,bb: o3d.geometry.OrientedBoundingBox, sn: SessionNode) -> PointCloudNode:
#     """adds a part to a point cloud.

#     Args:
        
            
#     Returns:
#         PointCloudNode containing the pointcloud of the cropped region
#     """
#     myCroppedPCD=pointcloud.resource.crop(bb)
#     if len(np.asarray(myCroppedPCD.points)) > 0:
#         if sn.resolution and len(np.asarray(myCroppedPCD.points)) >= 1000:
#             myCroppedPCD = myCroppedPCD.voxel_down_sample(sn.resolution)
#         target.resource.__iadd__(myCroppedPCD)
#         target.save_resource(sn.projectProcessingPath)

# %%
# def get_BIMNode(subject, sn : SessionNode):
#     """Gets the BIMNode  from which it is derived.

#     Args:
#         subject: the subject from which it was derived
#         BIMNodeList (List[BIMNodes]): list of all the BIMNodes in the project
            
#     Returns:
#         PointCloudNode containing the pointcloud of the cropped region
#     """
#     for n in sn.bimNodes:
#         if n.subject is subject:
#             return n

# %%
# def get_cropped_pcdNode(subject, sn : SessionNode):
#     for n in sn.meshpcdNodes:
#         if n.subject.split("-")[0] in subject:
#             return n

# %%
# #reset processed
# for meshpcdNode in sn.meshpcdNodes:
#     meshpcdNode.processed = False

# %%
sn.croppedpcdNodes  = []

for realPCD in sn.pcdPath:
    pointcloudnode = geomapi.nodes.PointCloudNode(path = realPCD, getResource = True)
    realorientedBB = gmu.get_oriented_bounding_box(pointcloudnode.cartesianBounds)
    realexpandedBB = gmu.expand_box(realorientedBB, u=1, v=1, w=1)

    for meshpcdNode in sn.meshpcdNodes:
        #Get the oriented boundingbox
        orientedBB = o3d.geometry.OrientedBoundingBox.get_oriented_bounding_box(meshpcdNode.resource)#gmu.get_oriented_bounding_box(meshpcdNode.cartesianBounds)
        expandedBB = gmu.expand_box(orientedBB, u=0.2, v=0.2, w=0)
        
        inliers = len(realexpandedBB.get_point_indices_within_bounding_box(expandedBB.get_box_points()))
        BIMNode = val.get_BIMNode(meshpcdNode.isDerivedFromGeometry, sn = sn)
         
        if inliers > 0 and meshpcdNode.resource is not None:
            if meshpcdNode.processed:
                
                myCroppedPCDNode = val.get_cropped_pcdNode(meshpcdNode.subject, sn = sn)
                val.add_to_croppedpcd(pointcloud = pointcloudnode, element= BIMNode, target=myCroppedPCDNode ,bb=expandedBB, sn = sn)
            else:
                myCroppedPCDNode = val.create_croppedpcd(pointcloud = pointcloudnode, element = BIMNode,  bb=expandedBB, sn = sn)
                if myCroppedPCDNode is not None:
                    sn.croppedpcdNodes.append(myCroppedPCDNode)
                    meshpcdNode.processed = True

# %%
# print(len(sn.croppedpcdNodes)) #232 bestanden
# print(len(sn.meshpcdNodes)) #241 bestanden

# %%
# #Check which elements where not cropped from the pointclouds
# for meshpcdnode in meshpcdNodes:
#     if not meshpcdnode.processed:
#         print(meshpcdnode.name)
#         # o3d.visualization.draw_geometries([meshpcdnode.resource, pointcloudnode.resource])
#         meshpcdnode.save_resource(projectPath)

# %% [markdown]
# 2. Filter the Cropped Pointcloud to remove as much Clutter as possible

# %%
def get_referenceCloudNode(subject, sn : SessionNode):
    succ = False
    for n in sn.meshpcdNodes:
        if n.subject.split("-")[0] in subject:
            succ = True
            return n
    if not succ:
        print(subject)

# %% [markdown]
# 2.1 Filtering on distance

# %%
# def distance_filtering(target: PointCloudNode, reference: PointCloudNode, sn : SessionNode):
    
#     d = target.resource.compute_point_cloud_distance(reference.resource)
    
#     i = 0
#     indeces = []

#     while i < len(d):
#         if d[i] < sn.Td:
#             indeces.append(i)
#         i += 1
    
#     BIMNode = get_BIMNode(reference.isDerivedFromGeometry, sn=sn)
    
#     if len(indeces) > 50:
#         filteredpcdNode = PointCloudNode(resource = target.resource.select_by_index(indeces),
#                                         subject=BIMNode.get_name().split("-")[0] + "-FILTEREDPCD",
#                                         name = BIMNode.get_name().split("-")[0] + "-FILTEREDPCD",
#                                         isDerivedFromGeometry=target.subject,
#                                         processingType = 'DISTANCE',
#                                         processed = False)
#         filteredpcdNode.path = os.path.join(sn.projectProcessingPath, filteredpcdNode.get_name() + ".pcd")
#         if os.path.exists(filteredpcdNode.path):
#             print("Path already exisits")
#             filteredpcdNode.path = os.path.join(sn.projectProcessingPath, filteredpcdNode.get_name() + time.strftime("%Y%m%d%H%M%S") +".pcd")
#         filteredpcdNode.save_resource(sn.projectProcessingPath)
       
#         return filteredpcdNode
#     else:
#         return None

# %% [markdown]
# 2.2 Filtering on distance and normal

# %%
# def normal_filtering(target: PointCloudNode, reference: PointCloudNode, sn : SessionNode):
#     if not target.resource.has_normals():
#         target.resource.estimate_normals()
#     if not reference.resource.has_normals():
#         reference.resource.estimate_normals()

#     d = target.resource.compute_point_cloud_distance(reference.resource)

#     i = 0
#     indeces_d = []

#     while i < len(d):
#         if d[i] < sn.Td:
#             indeces_d.append(i)
#         i += 1
    
#     BIMNode = get_BIMNode(reference.isDerivedFromGeometry, sn=sn)
    
#     if len(indeces_d) > 50:
#         indeces_n = []
#         kdtree = o3d.geometry.KDTreeFlann(reference.resource)
#         for id in indeces_d:
#             [k, idx, d] = kdtree.search_radius_vector_3d(target.resource.points[id], 0.1)
#             matched = False
#             i = 0
#             while not matched and i < len(idx) and len(idx) > 0:
#                 if np.abs(np.dot(np.asarray(target.resource.normals[id]), np.asarray(reference.resource.normals[idx[i]]))) > sn.Tdot:
#                     indeces_n.append(id)
#                     matched = True
#                 i += 1
#         if len(indeces_n) > 50:
#             filteredpcdNode = PointCloudNode(resource = target.resource.select_by_index(indeces_n),
#                                         subject=BIMNode.get_name().split("-")[0] + "-FILTEREDPCD",
#                                         name = BIMNode.get_name().split("-")[0] + "-FILTEREDPCD",
#                                         isDerivedFromGeometry=target.subject,
#                                         processingType = 'NORMALS',
#                                         processed = False)
#             filteredpcdNode.path = os.path.join(sn.projectProcessingPath, filteredpcdNode.get_name() + ".pcd")
#             if os.path.exists(filteredpcdNode.path):
#                 print("Path already exisits")
#                 filteredpcdNode.path = os.path.join(sn.projectProcessingPath, filteredpcdNode.get_name() + time.strftime("%Y%m%d%H%M%S") +".pcd")
#             filteredpcdNode.save_resource(sn.projectProcessingPath)
        
#             return filteredpcdNode
#         else: 
#             return None
#     else:
#         return None

# %%
sn.filteredPCDList1 = []

for pcdNode in sn.croppedpcdNodes:
    referenceNode = get_referenceCloudNode(subject = pcdNode.subject, sn= sn)
    try:
        # print(referenceNode.name)
        # filteredPCD = distance_filtering(target = pcdNode, reference = referenceNode, Treshold= 1)
        filteredPCD = val.normal_filtering(target =pcdNode, reference = referenceNode, sn = sn)
        if filteredPCD is not None:
            sn.filteredPCDList1.append(filteredPCD)
    except:
        print(pcdNode.subject)

# print(len(sn.filteredPCDList1))

# %% [markdown]
# ## Quality Control
# 1. Compute the LOA per element

# %%
# def color_by_LOA(target: PointCloudNode, distances: o3d.utility.DoubleVector, sn : SessionNode):
#     i=0
#     target.resource.paint_uniform_color([1,1,1])
#     # print(len(np.asarray(target.resource.points)))
#     # print(len(np.asarray(target.resource.colors)))
#     # print(len(np.asarray(distances)))
#     while i < len(distances):
#         distance = distances[i]
        
#         if distance < sn.t00:
#             np.asarray(target.resource.colors)[i] = [1,0,0]
#         if distance < sn.t10:
#             np.asarray(target.resource.colors)[i] = [1,0.76,0]
#         if distance < sn.t20:
#             np.asarray(target.resource.colors)[i] = [1,1,0]
#         if distance < sn.t30:
#             np.asarray(target.resource.colors)[i] = [0,1,0]
#         i += 1
    
#     pcdResultDirectory = os.path.join(sn.resultsPath, "PCD")
#     if not os.path.isdir(pcdResultDirectory): #check if the folder exists
#         os.mkdir(pcdResultDirectory)

#     target.save_resource(pcdResultDirectory)

# %%
# def compute_LOA(target: PointCloudNode, reference: PointCloudNode,sn : SessionNode):
#     d = target.resource.compute_point_cloud_distance(reference.resource)
    
#     LOA10Inliers = 0
#     LOA20Inliers = 0
#     LOA30Inliers = 0
#     LOA00Inliers = 0
#     totalPoints = len(d)

#     for dis in np.asarray(d):
#         if dis < sn.t00:
#             LOA00Inliers += 1
#         if dis < sn.t10:
#             LOA10Inliers += 1
#         if dis < sn.t20:
#             LOA20Inliers += 1
#         if dis < sn.t30: 
#             LOA30Inliers += 1
#     if LOA00Inliers < totalPoints:
#         prct = LOA00Inliers/totalPoints *100
    
#     if LOA00Inliers > 0:
#         LOA10 = LOA10Inliers/LOA00Inliers
#         LOA20 = LOA20Inliers/LOA00Inliers
#         LOA30 = LOA30Inliers/LOA00Inliers

#         color_by_LOA(target = target, distances=d, sn = sn)

#         return [LOA10, LOA20, LOA30]
#     else:
#         return None

# %%
# def LOA_to_csv(element : BIMNode, sn : SessionNode):
#     data = [element.name, element.globalId, element.key, element.accuracy, element.LOA10, element.LOA20, element.LOA30]
#     sn.csvWriter.writerow(data)

# def LOA_to_xlsx(element : BIMNode, sn : SessionNode):

#     sn.worksheet.write(sn.xlsxRow, 0, element.name)
#     sn.worksheet.write(sn.xlsxRow, 1, element.globalId)
#     sn.worksheet.write(sn.xlsxRow, 2, element.key)
#     sn.worksheet.write(sn.xlsxRow, 3, element.accuracy)
#     sn.worksheet.write(sn.xlsxRow, 4, element.LOA10)
#     sn.worksheet.write(sn.xlsxRow, 5, element.LOA20)
#     sn.worksheet.write(sn.xlsxRow, 6, element.LOA30)

#     sn.xlsxRow +=1


# def LOA_to_mesh(element : BIMNode, sn : SessionNode):
    
#     meshResultDirectory = os.path.join(sn.resultsPath, "PLY")
#     if not os.path.isdir(meshResultDirectory): #check if the folder exists
#         os.mkdir(meshResultDirectory)
    
#     meshResultName = element.name
#     meshResultFileName = meshResultName + ".ply"
#     meshResultPath = os.path.join(meshResultDirectory, meshResultFileName)

#     if not element.accuracy == "NO LOA":
#         if element.resource or os.path.exists(element.path):
#             loaded = False
#             if not element.resource and element.path:
#                 #Load the meshobject from disk
#                 element.resource = o3d.io.read_triangle_mesh(element.path)
#                 loaded = True
#         result = element.resource
#         if element.accuracy == "LOA30":
#             result.paint_uniform_color([0,1,0])
#         elif element.accuracy == "LOA20":
#             result.paint_uniform_color([1,1,0])
#         elif element.accuracy == "LOA10":
#             result.paint_uniform_color([1,0.76,0])
#         elif element.accuracy == "LOA00":
#             result.paint_uniform_color([1,0,0])
#         else:
#             result.paint_uniform_color([1,1,1])
        
#         if loaded:
#             element.resource = None
        
#         o3d.io.write_triangle_mesh(meshResultPath,result)
#         # print("OBJ file saved in %s" %meshResultPath)

#     else: 
#         print("ERROR no LOAs where computed in previous steps")

# %%
# def optimize_camera(node: Node):
    
#     fov = np.pi / 3 #60 #degrees
    
#     #determine extrinsic camera parameters
#     extrinsic = np.empty((1,3), dtype=float)
    
#     if node.resource is not None:
#         box=node.resource.get_oriented_bounding_box()
#         c = box.get_center()
#         u= box.extent[0]

#         d_w=math.cos(fov/2)*u
#         #determine c_i
#         rotation_matrix=box.R
#         pcd = o3d.geometry.PointCloud()
#         array=np.array([[c[0],c[1],c[2]+d_w]])
#         pcd.points = o3d.utility.Vector3dVector(array)
#         pcd.rotate(rotation_matrix, center =c)
#         c_i=np.asarray(pcd.points[0])

#         up = [0, 0, 1]  # camera orientation

#     return c,c_i,up

# %%
# def create_detail_image(resultpcd : PointCloudNode, sn : SessionNode, width = 640, height = 480):

#     referenceNode = get_referenceCloudNode(subject = resultpcd.subject, sn = sn)
#     bimnode = get_BIMNode(subject = referenceNode.isDerivedFromGeometry, sn = sn)
    
#     #generate scene
#     render = o3d.visualization.rendering.OffscreenRenderer(width,height)

#     #Determine the materials for visualization 
#     mtl=o3d.visualization.rendering.MaterialRecord()
#     mtl.base_color = [1.0, 1.0, 1.0, 1.0]  # RGBA
#     mtl.shader = "defaultUnlit"
    
#     mtlline=o3d.visualization.rendering.MaterialRecord()
#     mtlline.base_color = [0.0, 0.0, 0.0, 0.0]  # RGBA
#     mtlline.shader = "defaultUnlit"
    
#     #set camera
#     # # Look at the origin from the front (along the -Z direction, into the screen), with Y as Up.
#     center, eye, up = optimize_camera(bimnode)
#     render.scene.camera.look_at(center, eye, up)
    
#     #add geometries
#     if not bimnode.resource:
#         bimnode.get_resource()
#     #Add the BIM elements wireframe to the scene to have a bether understanding of the object
#     wireframe = o3d.geometry.LineSet.create_from_triangle_mesh(bimnode.resource)
#     wireframe.paint_uniform_color([0,0,0])
    
#     render.scene.add_geometry("test",resultpcd.resource,mtl)
#     render.scene.add_geometry("lines", wireframe, mtlline)

#     #render the image
#     img = render.render_to_image()
#     imageResultDirectory = os.path.join(sn.resultsPath, "IMAGES")
#     if not os.path.isdir(imageResultDirectory):
#         os.mkdir(imageResultDirectory)
#     detailImageResultName = bimnode.name
#     detailImageResultFileName = detailImageResultName + ".png"
#     detailImageResultPath = os.path.join(imageResultDirectory, detailImageResultFileName)

#     o3d.io.write_image(detailImageResultPath, img)
#     bimnode.detailImagePath = detailImageResultPath

# %%
# def create_report(resultpcd : PointCloudNode, sn : SessionNode):

#     referenceNode = get_referenceCloudNode(subject = resultpcd.subject, sn = sn)
#     bimnode = get_BIMNode(subject = referenceNode.isDerivedFromGeometry, sn = sn)

#     #Load both the detail and overview image of the object
#     detail = Image.open(bimnode.detailImagePath)
#     overview = Image.open(bimnode.overviewImagePath)

#     info = Image.new('RGB', (int(overview.width/2), int(overview.height/2)), color = (255,255,255))
#     d = ImageDraw.Draw(info)
#     d.text((10,10),bimnode.name, fill=(0,0,0))
#     d.text((10,20), time.strftime("%Y%m%d-%H%M%S"), fill=(0,0,0))
    
#     d.text((10,70),"LOA10  (%sm - %sm)" %(sn.t20,sn.t10), fill=(0,0,0))
#     if np.round(bimnode.LOA10, decimals = 2) < sn.p10:
#         d.text((200,70), str(np.round(bimnode.LOA10*100, decimals = 2)) + "%", fill=(255,0,0))
#     else:
#         d.text((200,70), str(np.round(bimnode.LOA10*100, decimals = 2))+ "%", fill=(0,255,0))
    
#     d.text((10,80), "LOA20  (%sm - %sm)" %(sn.t30, sn.t20), fill=(0,0,0))
#     if np.round(bimnode.LOA20, decimals = 2) < sn.p20:
#         d.text((200,80), str(np.round(bimnode.LOA20*100, decimals = 2))+ "%", fill=(255,0,0))
#     else:
#         d.text((200,80), str(np.round(bimnode.LOA20*100, decimals = 2))+ "%", fill=(0,255,0))

#     d.text((10,90), "LOA30  (%sm - %sm)" %(0, sn.t30), fill=(0,0,0))
#     if np.round(bimnode.LOA30, decimals = 2) < sn.p30:
#         d.text((200,90), str(np.round(bimnode.LOA30*100, decimals = 2))+ "%", fill=(255,0,0))
#     else:
#         d.text((200,90), str(np.round(bimnode.LOA30*100, decimals = 2))+ "%", fill=(0,255,0))
    

#     resizedInfo= info.resize((overview.width,overview.height), Image.ANTIALIAS)
#     info_overview = Image.new('RGB', (overview.width, overview.height*2))
#     info_overview.paste(resizedInfo, (0,0))
#     info_overview.paste(overview, (0,overview.height))

#     newHeigth = 2*overview.height
#     hpercent = (newHeigth/float(detail.height))
#     wsize = int((float(detail.width)*float(hpercent)))
#     resizedImage = detail.resize((wsize, newHeigth), Image.ANTIALIAS)

#     report = Image.new('RGB', (overview.width + wsize, overview.height*2))
#     report.paste(info_overview,(0,0))
#     report.paste(resizedImage, (info_overview.width, 0))

#     reportsResultDirectory = os.path.join(sn.resultsPath, "Reports")
#     if not os.path.isdir(reportsResultDirectory):
#         os.mkdir(reportsResultDirectory)
#     reportName = bimnode.name
#     reportFileName = reportName + ".png"
#     reportPath = os.path.join(reportsResultDirectory, reportFileName)

#     report.save(reportPath)

# %%
print(len(sn.filteredPCDList1))
for pcdNode in sn.filteredPCDList1:
    print(pcdNode)
    print(pcdNode.name)
    referenceNode = val.get_referenceCloudNode(subject = pcdNode.subject, sn = sn)
    LOAs = val.compute_LOA(target = pcdNode, reference=referenceNode, sn = sn)
    element = val.get_BIMNode(subject = referenceNode.isDerivedFromGeometry, sn = sn)
    print(element.name)
    #TODO: Consider overlap between pointclouds, how much of the object is observed to determine the reliability of the LOA prediction
    if not LOAs is None:
        element.LOA10 = LOAs[0]
        element.LOA20 = LOAs[1]
        element.LOA30 = LOAs[2]
        if LOAs[2] > sn.p30:
            element.accuracy = "LOA30"
        elif LOAs[1] > sn.p20:
            element.accuracy = "LOA20"
        elif LOAs[0] > sn.p10:
            element.accuracy = "LOA10"
        else:
            element.accuracy = "NO LOA"
    else:
        element.accuracy = "NO LOA"
        element.LOA10 = "NO"
        element.LOA20 = "NO"
        element.LOA30 = "NO"

    val.LOA_to_csv(element, sn = sn)
    val.LOA_to_xlsx(element,sn = sn)
    val.LOA_to_mesh(element, sn = sn)
    val.create_detail_image(resultpcd = pcdNode, sn = sn)
    try:
        val.create_report(pcdNode, sn=sn)
    except:
        print(pcdNode)
        print(element.name)
        print(element.resource)

csvFile.close()
sn.workbook.close()
